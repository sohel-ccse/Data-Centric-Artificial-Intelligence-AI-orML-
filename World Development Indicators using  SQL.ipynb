# %% [markdown]
# # Envrionment Setup

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/world-development-indicators/Series.csv
# /kaggle/input/world-development-indicators/database.sqlite
# /kaggle/input/world-development-indicators/SeriesNotes.csv
# /kaggle/input/world-development-indicators/Country.csv
# /kaggle/input/world-development-indicators/Footnotes.csv
# /kaggle/input/world-development-indicators/hashes.txt
# /kaggle/input/world-development-indicators/CountryNotes.csv
# /kaggle/input/world-development-indicators/Indicators.csv

# %% [markdown]
# # The purpose of this project was to practice SQL

# %% [markdown]
# * SQL stands for Structured Query Language and it is an ANSI standard computer language for accessing and manipulating database systems. It is used for managing data in relational database management system which stores data in the form of tables and relationship between data is also stored in the form of tables. SQL statements are used to retrieve and update data in a database

# %% [markdown]
# <img src="https://i.imgur.com/1riy1gs.jpg.jpg" width="800">

# %% [markdown]
# # # Import Libraries

# %%
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data read

# %%
conn = sqlite3.connect('../input/world-development-indicators/database.sqlite')

# %% [markdown]
# # SQL Retrieving Data from Tables

# %%
pd.read_sql(""" SELECT *
                FROM sqlite_master
                WHERE type='table';""",
           conn)
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table       Country       Country         2
# 1  table  CountryNotes  CountryNotes       186
# 2  table        Series        Series       948
# 3  table    Indicators    Indicators      4448
# 4  table   SeriesNotes   SeriesNotes   1317550
# 5  table     Footnotes     Footnotes   1317587
#
#                                                  sql
# 0  CREATE TABLE Country (\n    CountryCode TEXT,\...
# 1  CREATE TABLE CountryNotes (\n    Countrycode T...
# 2  CREATE TABLE Series (\n    SeriesCode TEXT,\n ...
# 3  CREATE TABLE Indicators (\n    CountryName TEX...
# 4  CREATE TABLE SeriesNotes (\n    Seriescode TEX...
# 5  CREATE TABLE Footnotes (\n    Countrycode TEXT...

# %%
pd.read_sql("""SELECT *
               FROM Indicators
               LIMIT 10;""",
           conn)
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
# 5  Arab World         ARB        Arms imports (SIPRI trend indicator values)
# 6  Arab World         ARB               Birth rate, crude (per 1,000 people)
# 7  Arab World         ARB                                 CO2 emissions (kt)
# 8  Arab World         ARB             CO2 emissions (metric tons per capita)
# 9  Arab World         ARB  CO2 emissions from gaseous fuel consumption (%...
#
#        IndicatorCode  Year         Value
# 0        SP.ADO.TFRT  1960  1.335609e+02
# 1        SP.POP.DPND  1960  8.779760e+01
# 2     SP.POP.DPND.OL  1960  6.634579e+00
# 3     SP.POP.DPND.YG  1960  8.102333e+01
# 4     MS.MIL.XPRT.KD  1960  3.000000e+06
# 5     MS.MIL.MPRT.KD  1960  5.380000e+08
# 6     SP.DYN.CBRT.IN  1960  4.769789e+01
# 7     EN.ATM.CO2E.KT  1960  5.956399e+04
# 8     EN.ATM.CO2E.PC  1960  6.439635e-01
# 9  EN.ATM.CO2E.GF.ZS  1960  5.041292e+00

# %%
#Displaying 3 numbers in 3 columns
pd.read_sql("""SELECT 5, 10, 15;""",
           conn)
# Out:
#    5  10  15
# 0  5  10  15

# %%
#The sum of 2 numbers
pd.read_sql("""SELECT 55+90;""",
           conn)
# Out:
#    55+90
# 0    145

# %%
#The result of an arithmetic expression
pd.read_sql("""SELECT 10+15-5*2;""",
           conn)
# Out:
#    10+15-5*2
# 0         15

# %% [markdown]
# # Displaying Year and Value

# %%
pd.read_sql("""SELECT Year, Value
               FROM Indicators;""",
           conn)
# Out:
#          Year         Value
# 0        1960  1.335609e+02
# 1        1960  8.779760e+01
# 2        1960  6.634579e+00
# 3        1960  8.102333e+01
# 4        1960  3.000000e+06
# ...       ...           ...
# 5656453  2015  3.600000e+01
# 5656454  2015  9.000000e+01
# 5656455  2015  2.420000e+02
# 5656456  2015  3.300000e+00
# 5656457  2015  3.280000e+01
#
# [5656458 rows x 2 columns]

# %%
pd.read_sql("""SELECT CountryName, CountryCode, IndicatorName
               FROM Indicators;""",
           conn)
# Out:
#         CountryName CountryCode  \
# 0        Arab World         ARB
# 1        Arab World         ARB
# 2        Arab World         ARB
# 3        Arab World         ARB
# 4        Arab World         ARB
# ...             ...         ...
# 5656453    Zimbabwe         ZWE
# 5656454    Zimbabwe         ZWE
# 5656455    Zimbabwe         ZWE
# 5656456    Zimbabwe         ZWE
# 5656457    Zimbabwe         ZWE
#
#                                              IndicatorName
# 0        Adolescent fertility rate (births per 1,000 wo...
# 1        Age dependency ratio (% of working-age populat...
# 2        Age dependency ratio, old (% of working-age po...
# 3        Age dependency ratio, young (% of working-age ...
# 4              Arms exports (SIPRI trend indicator values)
# ...                                                    ...
# 5656453          Time required to register property (days)
# 5656454           Time required to start a business (days)
# 5656455              Time to prepare and pay taxes (hours)
# 5656456                 Time to resolve insolvency (years)
# 5656457           Total tax rate (% of commercial profits)
#
# [5656458 rows x 3 columns]

# %%
#Retrieving the values of CountryName for all countries
pd.read_sql("""SELECT DISTINCT CountryName
               FROM Indicators;""",
           conn)
# Out:
#             CountryName
# 0           Afghanistan
# 1               Albania
# 2               Algeria
# 3        American Samoa
# 4               Andorra
# ..                  ...
# 242  West Bank and Gaza
# 243               World
# 244         Yemen, Rep.
# 245              Zambia
# 246            Zimbabwe
#
# [247 rows x 1 columns]

# %% [markdown]
# # SQL Filtering and Sorting

# %%
#Grouping and counting records by region
pd.read_sql("""SELECT Region, COUNT(*) AS [Count]
               FROM Country 
               GROUP BY Region
               ORDER BY 2 DESC;""",
            conn)
# Out:
#                        Region  Count
# 0       Europe & Central Asia     57
# 1          Sub-Saharan Africa     48
# 2   Latin America & Caribbean     41
# 3         East Asia & Pacific     36
# 4                                 33
# 5  Middle East & North Africa     21
# 6                  South Asia      8
# 7               North America      3

# %%
#Information about Canada
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE CountryName = "Canada";""",
           conn)
# Out:
#       CountryName CountryCode  \
# 0          Canada         CAN
# 1          Canada         CAN
# 2          Canada         CAN
# 3          Canada         CAN
# 4          Canada         CAN
# ...           ...         ...
# 24628      Canada         CAN
# 24629      Canada         CAN
# 24630      Canada         CAN
# 24631      Canada         CAN
# 24632      Canada         CAN
#
#                                            IndicatorName      IndicatorCode  \
# 0      Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 1      Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 2      Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 3      Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 4      Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
# ...                                                  ...                ...
# 24628          Time required to register property (days)        IC.PRP.DURS
# 24629           Time required to start a business (days)        IC.REG.DURS
# 24630              Time to prepare and pay taxes (hours)        IC.TAX.DURS
# 24631                 Time to resolve insolvency (years)        IC.ISV.DURS
# 24632           Total tax rate (% of commercial profits)  IC.TAX.TOTL.CP.ZS
#
#        Year       Value
# 0      1960   55.616600
# 1      1960   70.662096
# 2      1960   13.093013
# 3      1960   57.569083
# 4      1960   12.062296
# ...     ...         ...
# 24628  2015   16.500000
# 24629  2015    1.500000
# 24630  2015  131.000000
# 24631  2015    0.800000
# 24632  2015   21.100000
#
# [24633 rows x 6 columns]

# %%
#Displaying CountryName and Value which belong to the country of Singapore
pd.read_sql("""SELECT CountryName, Value
               FROM Indicators
               WHERE CountryName = "Singapore";""",
           conn)
# Out:
#       CountryName      Value
# 0       Singapore  56.997600
# 1       Singapore  82.778064
# 2       Singapore   3.735496
# 3       Singapore  79.042568
# 4       Singapore  38.500000
# ...           ...        ...
# 22595   Singapore   4.500000
# 22596   Singapore   2.500000
# 22597   Singapore  83.500000
# 22598   Singapore   0.800000
# 22599   Singapore  18.400000
#
# [22600 rows x 2 columns]

# %%
#Information for the countries from the year of 2000
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE Year = "2000";""",
           conn)
# Out:
#        CountryName CountryCode  \
# 0       Arab World         ARB
# 1       Arab World         ARB
# 2       Arab World         ARB
# 3       Arab World         ARB
# 4       Arab World         ARB
# ...            ...         ...
# 154723    Zimbabwe         ZWE
# 154724    Zimbabwe         ZWE
# 154725    Zimbabwe         ZWE
# 154726    Zimbabwe         ZWE
# 154727    Zimbabwe         ZWE
#
#                                             IndicatorName      IndicatorCode  \
# 0                 Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 1       Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2       Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 3              Access to non-solid fuel (% of population)     EG.NSF.ACCS.ZS
# 4       Adjusted net enrolment rate, primary, both sex...        SE.PRM.TENR
# ...                                                   ...                ...
# 154723                                   Urban population        SP.URB.TOTL
# 154724                      Urban population (% of total)  SP.URB.TOTL.IN.ZS
# 154725                 Urban population growth (annual %)        SP.URB.GROW
# 154726               Use of IMF credit (DOD, current US$)     DT.DOD.DIMF.CD
# 154727  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
#
#         Year         Value
# 0       2000  7.953695e+01
# 1       2000  6.586906e+01
# 2       2000  9.165462e+01
# 3       2000  8.156521e+01
# 4       2000  7.848897e+01
# ...      ...           ...
# 154723  2000  4.219744e+06
# 154724  2000  3.375800e+01
# 154725  2000  2.237783e+00
# 154726  2000  2.939490e+08
# 154727  2000  5.663196e+01
#
# [154728 rows x 6 columns]

# %%
#IndicatorName and IndicatorCode for the country that holds the CountryCode "ARB"
pd.read_sql("""SELECT IndicatorName, IndicatorCode
               FROM Indicators
               WHERE CountryCode = "ARB";""",
           conn)
# Out:
#                                            IndicatorName      IndicatorCode
# 0      Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 1      Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 2      Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 3      Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 4            Arms exports (SIPRI trend indicator values)     MS.MIL.XPRT.KD
# ...                                                  ...                ...
# 17110          Time required to register property (days)        IC.PRP.DURS
# 17111           Time required to start a business (days)        IC.REG.DURS
# 17112              Time to prepare and pay taxes (hours)        IC.TAX.DURS
# 17113                 Time to resolve insolvency (years)        IC.ISV.DURS
# 17114           Total tax rate (% of commercial profits)  IC.TAX.TOTL.CP.ZS
#
# [17115 rows x 2 columns]

# %%
#Values for Switzerland since 1990

# %%
pd.read_sql("""SELECT Value
               FROM Indicators
               WHERE Year >=1990
               AND CountryName = "Switzerland";""",
           conn)
# Out:
#            Value
# 0      100.00000
# 1      100.00000
# 2      100.00000
# 3      100.00000
# 4       83.32286
# ...          ...
# 15792   16.00000
# 15793   10.00000
# 15794   63.00000
# 15795    3.00000
# 15796   28.80000
#
# [15797 rows x 1 columns]

# %%
#Values for the United States between 1971 and 1990 inclusive
pd.read_sql("""SELECT Value
               FROM Indicators
               WHERE CountryName = "United States"
               AND Year>=1971 AND Year<=1990;""",
           conn)
# Out:
#              Value
# 0     2.725188e+00
# 1     3.932165e+12
# 2     1.007091e+12
# 3     1.434575e+00
# 4     1.893550e+04
# ...            ...
# 7258  1.410256e+00
# 7259  9.330000e+01
# 7260  9.120000e+01
# 7261  8.950000e+01
# 7262  6.292403e+01
#
# [7263 rows x 1 columns]

# %%
#All the details of Central African Republic and Rwanda after 1999
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE Year >1999
               AND CountryName IN ('Central African Republic',
               'Rwanda');""",
           conn)
# Out:
#                     CountryName CountryCode  \
# 0      Central African Republic         CAF
# 1      Central African Republic         CAF
# 2      Central African Republic         CAF
# 3      Central African Republic         CAF
# 4      Central African Republic         CAF
# ...                         ...         ...
# 23592                    Rwanda         RWA
# 23593                    Rwanda         RWA
# 23594                    Rwanda         RWA
# 23595                    Rwanda         RWA
# 23596                    Rwanda         RWA
#
#                                            IndicatorName      IndicatorCode  \
# 0                Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 1      Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2      Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 3             Access to non-solid fuel (% of population)     EG.NSF.ACCS.ZS
# 4       Adjusted net national income (constant 2005 US$)     NY.ADJ.NNTY.KD
# ...                                                  ...                ...
# 23592          Time required to register property (days)        IC.PRP.DURS
# 23593           Time required to start a business (days)        IC.REG.DURS
# 23594              Time to prepare and pay taxes (hours)        IC.TAX.DURS
# 23595                 Time to resolve insolvency (years)        IC.ISV.DURS
# 23596           Total tax rate (% of commercial profits)  IC.TAX.TOTL.CP.ZS
#
#        Year         Value
# 0      2000  6.000000e+00
# 1      2000  7.000000e-01
# 2      2000  1.478114e+01
# 3      2000  2.492583e+00
# 4      2000  1.101137e+09
# ...     ...           ...
# 23592  2015  3.200000e+01
# 23593  2015  5.500000e+00
# 23594  2015  1.090000e+02
# 23595  2015  2.500000e+00
# 23596  2015  3.300000e+01
#
# [23597 rows x 6 columns]

# %%
#Information about GDP
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE IndicatorName LIKE 'GDP%';""",
           conn)
# Out:
#                                     CountryName CountryCode  \
# 0                        Caribbean small states         CSS
# 1                        Caribbean small states         CSS
# 2       East Asia & Pacific (all income levels)         EAS
# 3       East Asia & Pacific (all income levels)         EAS
# 4       East Asia & Pacific (all income levels)         EAS
# ...                                         ...         ...
# 138019                                 Zimbabwe         ZWE
# 138020                                 Zimbabwe         ZWE
# 138021                                 Zimbabwe         ZWE
# 138022                                 Zimbabwe         ZWE
# 138023                                 Zimbabwe         ZWE
#
#                                             IndicatorName      IndicatorCode  \
# 0                      GDP at market prices (current US$)     NY.GDP.MKTP.CD
# 1                            GDP per capita (current US$)     NY.GDP.PCAP.CD
# 2                GDP at market prices (constant 2005 US$)     NY.GDP.MKTP.KD
# 3                      GDP at market prices (current US$)     NY.GDP.MKTP.CD
# 4                      GDP per capita (constant 2005 US$)     NY.GDP.PCAP.KD
# ...                                                   ...                ...
# 138019  GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
# 138020      GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
# 138021      GDP per person employed (constant 1990 PPP $)  SL.GDP.PCAP.EM.KD
# 138022           GDP, PPP (constant 2011 international $)  NY.GDP.MKTP.PP.KD
# 138023                 GDP, PPP (current international $)  NY.GDP.MKTP.PP.CD
#
#         Year         Value
# 0       1960  1.917148e+09
# 1       1960  4.574647e+02
# 2       1960  1.023739e+12
# 3       1960  1.530501e+11
# 4       1960  9.820268e+02
# ...      ...           ...
# 138019  2014  1.709144e+03
# 138020  2014  1.791514e+03
# 138021  2014  3.716000e+03
# 138022  2014  2.605736e+10
# 138023  2014  2.731316e+10
#
# [138024 rows x 6 columns]

# %%
#Details for Finland of 2013 and Peru of 2014 together
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE (CountryName = "Finland" AND Year=2013)
               UNION SELECT *
               FROM Indicators
               WHERE (CountryName = "Peru" AND Year=2014);""",
           conn)
# Out:
#      CountryName CountryCode  \
# 0        Finland         FIN
# 1        Finland         FIN
# 2        Finland         FIN
# 3        Finland         FIN
# 4        Finland         FIN
# ...          ...         ...
# 1222        Peru         PER
# 1223        Peru         PER
# 1224        Peru         PER
# 1225        Peru         PER
# 1226        Peru         PER
#
#                                           IndicatorName      IndicatorCode  \
# 0     Adjusted net enrolment rate, primary, both sex...        SE.PRM.TENR
# 1      Adjusted net enrolment rate, primary, female (%)     SE.PRM.TENR.FE
# 2        Adjusted net enrolment rate, primary, male (%)     SE.PRM.TENR.MA
# 3        Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 4      Adjusted net national income (constant 2005 US$)     NY.ADJ.NNTY.KD
# ...                                                 ...                ...
# 1222    Urban poverty gap at national poverty lines (%)        SI.POV.URGP
# 1223  Urban poverty headcount ratio at national pove...        SI.POV.URHC
# 1224               Use of IMF credit (DOD, current US$)     DT.DOD.DIMF.CD
# 1225                 Wholesale price index (2010 = 100)        FP.WPI.TOTL
# 1226  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
#
#       Year         Value
# 0     2013  9.913012e+01
# 1     2013  9.943423e+01
# 2     2013  9.884058e+01
# 3     2013 -1.430165e+00
# 4     2013  1.660762e+11
# ...    ...           ...
# 1222  2014  3.300000e+00
# 1223  2014  1.530000e+01
# 1224  2014  8.836190e+08
# 1225  2014  1.106242e+02
# 1226  2014  3.004451e+01
#
# [1227 rows x 6 columns]

# %%
#Showing information about the countries in the year 2015 except BD
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE Year=2015
               AND CountryName NOT IN ('Bangladesh');""",
           conn)
# Out:
#       CountryName CountryCode  \
# 0      Arab World         ARB
# 1      Arab World         ARB
# 2      Arab World         ARB
# 3      Arab World         ARB
# 4      Arab World         ARB
# ...           ...         ...
# 14683    Zimbabwe         ZWE
# 14684    Zimbabwe         ZWE
# 14685    Zimbabwe         ZWE
# 14686    Zimbabwe         ZWE
# 14687    Zimbabwe         ZWE
#
#                                            IndicatorName      IndicatorCode  \
# 0                               Bird species, threatened     EN.BIR.THRD.NO
# 1      Business extent of disclosure index (0=less di...     IC.BUS.DISC.XQ
# 2      Cost of business start-up procedures (% of GNI...  IC.REG.COST.PC.ZS
# 3      Depth of credit information index (0=low to 8=...     IC.CRD.INFO.XQ
# 4      Distance to frontier score (0=lowest performan...     IC.BUS.DFRN.XQ
# ...                                                  ...                ...
# 14683          Time required to register property (days)        IC.PRP.DURS
# 14684           Time required to start a business (days)        IC.REG.DURS
# 14685              Time to prepare and pay taxes (hours)        IC.TAX.DURS
# 14686                 Time to resolve insolvency (years)        IC.ISV.DURS
# 14687           Total tax rate (% of commercial profits)  IC.TAX.TOTL.CP.ZS
#
#        Year       Value
# 0      2015  297.000000
# 1      2015    5.666667
# 2      2015   31.142857
# 3      2015    3.714286
# 4      2015   54.491905
# ...     ...         ...
# 14683  2015   36.000000
# 14684  2015   90.000000
# 14685  2015  242.000000
# 14686  2015    3.300000
# 14687  2015   32.800000
#
# [14688 rows x 6 columns]

# %%
#IndicatorName for the countries not started with the letter 'P' and arranged the list as the most recent comes first, then by name in order
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE CountryName NOT LIKE 'P%'
               ORDER BY YEAR DESC, IndicatorName;""",
           conn)
# Out:
#                       CountryName CountryCode  \
# 0                          Bhutan         BTN
# 1              West Bank and Gaza         WBG
# 2                      Uzbekistan         UZB
# 3                   United States         USA
# 4                         Ukraine         UKR
# ...                           ...         ...
# 5373692  Central African Republic         CAF
# 5373693                    Canada         CAN
# 5373694                    Brazil         BRA
# 5373695                   Austria         AUT
# 5373696                 Australia         AUS
#
#                                              IndicatorName   IndicatorCode  \
# 0        Average time to clear exports through customs ...  IC.CUS.DURS.EX
# 1                         Bank capital to assets ratio (%)  FB.BNK.CAPA.ZS
# 2                         Bank capital to assets ratio (%)  FB.BNK.CAPA.ZS
# 3                         Bank capital to assets ratio (%)  FB.BNK.CAPA.ZS
# 4                         Bank capital to assets ratio (%)  FB.BNK.CAPA.ZS
# ...                                                    ...             ...
# 5373692                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
# 5373693                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
# 5373694                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
# 5373695                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
# 5373696                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
#
#          Year         Value
# 0        2015  1.270000e+01
# 1        2015  9.674752e+00
# 2        2015  1.129908e+01
# 3        2015  1.162816e+01
# 4        2015  7.642274e+00
# ...       ...           ...
# 5373692  1960  7.526927e+00
# 5373693  1960  1.639533e+01
# 5373694  1960  2.448357e-13
# 5373695  1960  3.090663e+01
# 5373696  1960  1.069203e+01
#
# [5373697 rows x 6 columns]

# %%
#IndicatorName for the countries not started with the letter 'S' and arranged the list as the most recent comes first, then by name in order
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE CountryName NOT LIKE 'S%'
               ORDER BY YEAR DESC, IndicatorName;""",
           conn)
# Out:
#                       CountryName CountryCode  \
# 0                          Bhutan         BTN
# 1              West Bank and Gaza         WBG
# 2                      Uzbekistan         UZB
# 3                   United States         USA
# 4                         Ukraine         UKR
# ...                           ...         ...
# 4979332  Central African Republic         CAF
# 4979333                    Canada         CAN
# 4979334                    Brazil         BRA
# 4979335                   Austria         AUT
# 4979336                 Australia         AUS
#
#                                              IndicatorName   IndicatorCode  \
# 0        Average time to clear exports through customs ...  IC.CUS.DURS.EX
# 1                         Bank capital to assets ratio (%)  FB.BNK.CAPA.ZS
# 2                         Bank capital to assets ratio (%)  FB.BNK.CAPA.ZS
# 3                         Bank capital to assets ratio (%)  FB.BNK.CAPA.ZS
# 4                         Bank capital to assets ratio (%)  FB.BNK.CAPA.ZS
# ...                                                    ...             ...
# 4979332                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
# 4979333                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
# 4979334                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
# 4979335                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
# 4979336                 Wholesale price index (2010 = 100)     FP.WPI.TOTL
#
#          Year         Value
# 0        2015  1.270000e+01
# 1        2015  9.674752e+00
# 2        2015  1.129908e+01
# 3        2015  1.162816e+01
# 4        2015  7.642274e+00
# ...       ...           ...
# 4979332  1960  7.526927e+00
# 4979333  1960  1.639533e+01
# 4979334  1960  2.448357e-13
# 4979335  1960  3.090663e+01
# 4979336  1960  1.069203e+01
#
# [4979337 rows x 6 columns]

# %%
#Countries with the Value between 100 and 500
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE Value BETWEEN 100 AND 500;""",
           conn)
# Out:
#        CountryName CountryCode  \
# 0       Arab World         ARB
# 1       Arab World         ARB
# 2       Arab World         ARB
# 3       Arab World         ARB
# 4       Arab World         ARB
# ...            ...         ...
# 201685    Zimbabwe         ZWE
# 201686    Zimbabwe         ZWE
# 201687    Zimbabwe         ZWE
# 201688    Zimbabwe         ZWE
# 201689    Zimbabwe         ZWE
#
#                                             IndicatorName   IndicatorCode  \
# 0       Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT
# 1       Mortality rate, adult, female (per 1,000 femal...  SP.DYN.AMRT.FE
# 2       Mortality rate, adult, male (per 1,000 male ad...  SP.DYN.AMRT.MA
# 3          Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN
# 4                     Mortality rate, under-5 (per 1,000)     SH.DYN.MORT
# ...                                                   ...             ...
# 201685  Maternal mortality ratio (modeled estimate, pe...     SH.STA.MMRT
# 201686          Time required to build a warehouse (days)     IC.WRH.DURS
# 201687         Time required to enforce a contract (days)     IC.LGL.DURS
# 201688            Time required to get electricity (days)     IC.ELC.TIME
# 201689              Time to prepare and pay taxes (hours)     IC.TAX.DURS
#
#         Year       Value
# 0       1960  133.560907
# 1       1960  298.935703
# 2       1960  357.705584
# 3       1960  159.950234
# 4       1960  249.360225
# ...      ...         ...
# 201685  2015  443.000000
# 201686  2015  448.000000
# 201687  2015  410.000000
# 201688  2015  106.000000
# 201689  2015  242.000000
#
# [201690 rows x 6 columns]

# %%
#Countries with the Value between 100 and 500
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE Value BETWEEN 100 AND 500;""",
           conn)
# Out:
#        CountryName CountryCode  \
# 0       Arab World         ARB
# 1       Arab World         ARB
# 2       Arab World         ARB
# 3       Arab World         ARB
# 4       Arab World         ARB
# ...            ...         ...
# 201685    Zimbabwe         ZWE
# 201686    Zimbabwe         ZWE
# 201687    Zimbabwe         ZWE
# 201688    Zimbabwe         ZWE
# 201689    Zimbabwe         ZWE
#
#                                             IndicatorName   IndicatorCode  \
# 0       Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT
# 1       Mortality rate, adult, female (per 1,000 femal...  SP.DYN.AMRT.FE
# 2       Mortality rate, adult, male (per 1,000 male ad...  SP.DYN.AMRT.MA
# 3          Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN
# 4                     Mortality rate, under-5 (per 1,000)     SH.DYN.MORT
# ...                                                   ...             ...
# 201685  Maternal mortality ratio (modeled estimate, pe...     SH.STA.MMRT
# 201686          Time required to build a warehouse (days)     IC.WRH.DURS
# 201687         Time required to enforce a contract (days)     IC.LGL.DURS
# 201688            Time required to get electricity (days)     IC.ELC.TIME
# 201689              Time to prepare and pay taxes (hours)     IC.TAX.DURS
#
#         Year       Value
# 0       1960  133.560907
# 1       1960  298.935703
# 2       1960  357.705584
# 3       1960  159.950234
# 4       1960  249.360225
# ...      ...         ...
# 201685  2015  443.000000
# 201686  2015  448.000000
# 201687  2015  410.000000
# 201688  2015  106.000000
# 201689  2015  242.000000
#
# [201690 rows x 6 columns]

# %% [markdown]
# # SQL Aggregate Functions

# %%
#Calculating the average value of urban population
pd.read_sql("""SELECT AVG(Value)
               FROM Indicators
               WHERE IndicatorName = 'Urban population';""",
           conn)
# Out:
#      AVG(Value)
# 0  6.240680e+07

# %%
#The lowest GDP per capita in 2014
pd.read_sql("""SELECT CountryName, MIN (Value)
               FROM Indicators
               WHERE IndicatorName = 'GDP per capita (current US$)'
               AND Year = 2014;""",
            conn)
# Out:
#   CountryName  MIN (Value)
# 0      Malawi    255.04457

# %%
#Country Name and Country Code
pd.read_sql("""SELECT CountryName as "Country Name", CountryCode as "Country Code"
               FROM Indicators;""",
            conn)
# Out:
#         Country Name Country Code
# 0         Arab World          ARB
# 1         Arab World          ARB
# 2         Arab World          ARB
# 3         Arab World          ARB
# 4         Arab World          ARB
# ...              ...          ...
# 5656453     Zimbabwe          ZWE
# 5656454     Zimbabwe          ZWE
# 5656455     Zimbabwe          ZWE
# 5656456     Zimbabwe          ZWE
# 5656457     Zimbabwe          ZWE
#
# [5656458 rows x 2 columns]

# %%
#Displaying the countries with the highest GDP per capita in 2012
pd.read_sql("""SELECT * 
               FROM Indicators
               WHERE IndicatorName='GDP per capita (current US$)'
               AND Year= 2012
               ORDER BY Value DESC
               LIMIT 10;""",
           conn)
# Out:
#         CountryName CountryCode                 IndicatorName   IndicatorCode  \
# 0     Liechtenstein         LIE  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1        Luxembourg         LUX  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2            Norway         NOR  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3             Qatar         QAT  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4           Bermuda         BMU  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 5       Switzerland         CHE  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 6  Macao SAR, China         MAC  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 7         Australia         AUS  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 8           Denmark         DNK  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 9            Sweden         SWE  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
#    Year          Value
# 0  2012  149160.758132
# 1  2012  105447.093241
# 2  2012  101563.702678
# 3  2012   94407.406920
# 4  2012   85458.455508
# 5  2012   83208.686542
# 6  2012   77078.821183
# 7  2012   67646.103853
# 8  2012   57636.125310
# 9  2012   57134.077068

# %%
#Comparing Life expectancy at birth max values for miltiple countries from 2014 inclusive
pd.read_sql(""" SELECT CountryName, MAX(Value)
                FROM Indicators
                WHERE IndicatorName= 'Life expectancy at birth, total (years)'
                AND CountryName IN ('Canada', 'Switzerland',
                'United States', 'Australia', 'Singapore')
                AND Year>=2013
                GROUP BY CountryName;""",
           conn)
# Out:
#      CountryName  MAX(Value)
# 0      Australia   82.197561
# 1         Canada   81.401122
# 2      Singapore   82.346341
# 3    Switzerland   82.748780
# 4  United States   78.841463

# %%
#Death rate in Latin America
pd.read_sql("""SELECT *
               FROM Indicators
               WHERE IndicatorName='Death rate, crude (per 1,000 people)'
               AND CountryName LIKE 'Latin America%'
               ORDER BY Value ASC;""",
           conn)
# Out:
#                                        CountryName CountryCode  \
# 0      Latin America & Caribbean (developing only)         LAC
# 1      Latin America & Caribbean (developing only)         LAC
# 2      Latin America & Caribbean (developing only)         LAC
# 3      Latin America & Caribbean (developing only)         LAC
# 4      Latin America & Caribbean (developing only)         LAC
# ..                                             ...         ...
# 103    Latin America & Caribbean (developing only)         LAC
# 104  Latin America & Caribbean (all income levels)         LCN
# 105    Latin America & Caribbean (developing only)         LAC
# 106    Latin America & Caribbean (developing only)         LAC
# 107    Latin America & Caribbean (developing only)         LAC
#
#                             IndicatorName   IndicatorCode  Year      Value
# 0    Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  2006   5.641006
# 1    Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  2005   5.643475
# 2    Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  2007   5.644845
# 3    Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  2008   5.650285
# 4    Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  2004   5.655212
# ..                                    ...             ...   ...        ...
# 103  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  1963  12.801260
# 104  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  1960  13.012060
# 105  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  1962  13.139747
# 106  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  1961  13.486745
# 107  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  1960  13.843268
#
# [108 rows x 6 columns]

# %%
#Null values
pd.read_sql("""SELECT COUNT(*)
               FROM Indicators
               WHERE IndicatorName IS NULL;""",
           conn)
# Out:
#    COUNT(*)
# 0         0

# %%
#The sum of hospital beds
pd.read_sql("""SELECT SUM(Value)
               FROM Indicators
               WHERE IndicatorName = 'Hospital beds (per 1,000 people)';""",
           conn)
# Out:
#      SUM(Value)
# 0  16329.169032

# %% [markdown]
# # SQL Join

# %%
#Fertility rate in Norway
pd.read_sql(""" SELECT Indicators.*, Series.LongDefinition
                FROM Indicators
                LEFT JOIN Series 
                ON Indicators.IndicatorName  = Series.IndicatorName
                WHERE Indicators.IndicatorName LIKE 'Fertility rate%'
                AND CountryName ='Norway';""",
            conn)
# Out:
#    CountryName CountryCode                             IndicatorName  \
# 0       Norway         NOR  Fertility rate, total (births per woman)
# 1       Norway         NOR  Fertility rate, total (births per woman)
# 2       Norway         NOR  Fertility rate, total (births per woman)
# 3       Norway         NOR  Fertility rate, total (births per woman)
# 4       Norway         NOR  Fertility rate, total (births per woman)
# 5       Norway         NOR  Fertility rate, total (births per woman)
# 6       Norway         NOR  Fertility rate, total (births per woman)
# 7       Norway         NOR  Fertility rate, total (births per woman)
# 8       Norway         NOR  Fertility rate, total (births per woman)
# 9       Norway         NOR  Fertility rate, total (births per woman)
# 10      Norway         NOR  Fertility rate, total (births per woman)
# 11      Norway         NOR  Fertility rate, total (births per woman)
# 12      Norway         NOR  Fertility rate, total (births per woman)
# 13      Norway         NOR  Fertility rate, total (births per woman)
# 14      Norway         NOR  Fertility rate, total (births per woman)
# 15      Norway         NOR  Fertility rate, total (births per woman)
# 16      Norway         NOR  Fertility rate, total (births per woman)
# 17      Norway         NOR  Fertility rate, total (births per woman)
# 18      Norway         NOR  Fertility rate, total (births per woman)
# 19      Norway         NOR  Fertility rate, total (births per woman)
# 20      Norway         NOR  Fertility rate, total (births per woman)
# 21      Norway         NOR  Fertility rate, total (births per woman)
# 22      Norway         NOR  Fertility rate, total (births per woman)
# 23      Norway         NOR  Fertility rate, total (births per woman)
# 24      Norway         NOR  Fertility rate, total (births per woman)
# 25      Norway         NOR  Fertility rate, total (births per woman)
# 26      Norway         NOR  Fertility rate, total (births per woman)
# 27      Norway         NOR  Fertility rate, total (births per woman)
# 28      Norway         NOR  Fertility rate, total (births per woman)
# 29      Norway         NOR  Fertility rate, total (births per woman)
# 30      Norway         NOR  Fertility rate, total (births per woman)
# 31      Norway         NOR  Fertility rate, total (births per woman)
# 32      Norway         NOR  Fertility rate, total (births per woman)
# 33      Norway         NOR  Fertility rate, total (births per woman)
# 34      Norway         NOR  Fertility rate, total (births per woman)
# 35      Norway         NOR  Fertility rate, total (births per woman)
# 36      Norway         NOR  Fertility rate, total (births per woman)
# 37      Norway         NOR  Fertility rate, total (births per woman)
# 38      Norway         NOR  Fertility rate, total (births per woman)
# 39      Norway         NOR  Fertility rate, total (births per woman)
# 40      Norway         NOR  Fertility rate, total (births per woman)
# 41      Norway         NOR  Fertility rate, total (births per woman)
# 42      Norway         NOR  Fertility rate, total (births per woman)
# 43      Norway         NOR  Fertility rate, total (births per woman)
# 44      Norway         NOR  Fertility rate, total (births per woman)
# 45      Norway         NOR  Fertility rate, total (births per woman)
# 46      Norway         NOR  Fertility rate, total (births per woman)
# 47      Norway         NOR  Fertility rate, total (births per woman)
# 48      Norway         NOR  Fertility rate, total (births per woman)
# 49      Norway         NOR  Fertility rate, total (births per woman)
# 50      Norway         NOR  Fertility rate, total (births per woman)
# 51      Norway         NOR  Fertility rate, total (births per woman)
# 52      Norway         NOR  Fertility rate, total (births per woman)
# 53      Norway         NOR  Fertility rate, total (births per woman)
#
#      IndicatorCode  Year  Value  \
# 0   SP.DYN.TFRT.IN  1960   2.85
# 1   SP.DYN.TFRT.IN  1961   2.94
# 2   SP.DYN.TFRT.IN  1962   2.91
# 3   SP.DYN.TFRT.IN  1963   2.93
# 4   SP.DYN.TFRT.IN  1964   2.98
# 5   SP.DYN.TFRT.IN  1965   2.94
# 6   SP.DYN.TFRT.IN  1966   2.90
# 7   SP.DYN.TFRT.IN  1967   2.81
# 8   SP.DYN.TFRT.IN  1968   2.75
# 9   SP.DYN.TFRT.IN  1969   2.70
# 10  SP.DYN.TFRT.IN  1970   2.50
# 11  SP.DYN.TFRT.IN  1971   2.49
# 12  SP.DYN.TFRT.IN  1972   2.38
# 13  SP.DYN.TFRT.IN  1973   2.23
# 14  SP.DYN.TFRT.IN  1974   2.13
# 15  SP.DYN.TFRT.IN  1975   1.98
# 16  SP.DYN.TFRT.IN  1976   1.86
# 17  SP.DYN.TFRT.IN  1977   1.75
# 18  SP.DYN.TFRT.IN  1978   1.77
# 19  SP.DYN.TFRT.IN  1979   1.75
# 20  SP.DYN.TFRT.IN  1980   1.72
# 21  SP.DYN.TFRT.IN  1981   1.70
# 22  SP.DYN.TFRT.IN  1982   1.71
# 23  SP.DYN.TFRT.IN  1983   1.66
# 24  SP.DYN.TFRT.IN  1984   1.66
# 25  SP.DYN.TFRT.IN  1985   1.68
# 26  SP.DYN.TFRT.IN  1986   1.71
# 27  SP.DYN.TFRT.IN  1987   1.74
# 28  SP.DYN.TFRT.IN  1988   1.84
# 29  SP.DYN.TFRT.IN  1989   1.89
# 30  SP.DYN.TFRT.IN  1990   1.93
# 31  SP.DYN.TFRT.IN  1991   1.92
# 32  SP.DYN.TFRT.IN  1992   1.88
# 33  SP.DYN.TFRT.IN  1993   1.86
# 34  SP.DYN.TFRT.IN  1994   1.87
# 35  SP.DYN.TFRT.IN  1995   1.87
# 36  SP.DYN.TFRT.IN  1996   1.89
# 37  SP.DYN.TFRT.IN  1997   1.86
# 38  SP.DYN.TFRT.IN  1998   1.81
# 39  SP.DYN.TFRT.IN  1999   1.85
# 40  SP.DYN.TFRT.IN  2000   1.85
# 41  SP.DYN.TFRT.IN  2001   1.78
# 42  SP.DYN.TFRT.IN  2002   1.75
# 43  SP.DYN.TFRT.IN  2003   1.80
# 44  SP.DYN.TFRT.IN  2004   1.83
# 45  SP.DYN.TFRT.IN  2005   1.84
# 46  SP.DYN.TFRT.IN  2006   1.90
# 47  SP.DYN.TFRT.IN  2007   1.90
# 48  SP.DYN.TFRT.IN  2008   1.96
# 49  SP.DYN.TFRT.IN  2009   1.98
# 50  SP.DYN.TFRT.IN  2010   1.95
# 51  SP.DYN.TFRT.IN  2011   1.88
# 52  SP.DYN.TFRT.IN  2012   1.85
# 53  SP.DYN.TFRT.IN  2013   1.85
#
#                                        LongDefinition
# 0   Total fertility rate represents the number of ...
# 1   Total fertility rate represents the number of ...
# 2   Total fertility rate represents the number of ...
# 3   Total fertility rate represents the number of ...
# 4   Total fertility rate represents the number of ...
# 5   Total fertility rate represents the number of ...
# 6   Total fertility rate represents the number of ...
# 7   Total fertility rate represents the number of ...
# 8   Total fertility rate represents the number of ...
# 9   Total fertility rate represents the number of ...
# 10  Total fertility rate represents the number of ...
# 11  Total fertility rate represents the number of ...
# 12  Total fertility rate represents the number of ...
# 13  Total fertility rate represents the number of ...
# 14  Total fertility rate represents the number of ...
# 15  Total fertility rate represents the number of ...
# 16  Total fertility rate represents the number of ...
# 17  Total fertility rate represents the number of ...
# 18  Total fertility rate represents the number of ...
# 19  Total fertility rate represents the number of ...
# 20  Total fertility rate represents the number of ...
# 21  Total fertility rate represents the number of ...
# 22  Total fertility rate represents the number of ...
# 23  Total fertility rate represents the number of ...
# 24  Total fertility rate represents the number of ...
# 25  Total fertility rate represents the number of ...
# 26  Total fertility rate represents the number of ...
# 27  Total fertility rate represents the number of ...
# 28  Total fertility rate represents the number of ...
# 29  Total fertility rate represents the number of ...
# 30  Total fertility rate represents the number of ...
# 31  Total fertility rate represents the number of ...
# 32  Total fertility rate represents the number of ...
# 33  Total fertility rate represents the number of ...
# 34  Total fertility rate represents the number of ...
# 35  Total fertility rate represents the number of ...
# 36  Total fertility rate represents the number of ...
# 37  Total fertility rate represents the number of ...
# 38  Total fertility rate represents the number of ...
# 39  Total fertility rate represents the number of ...
# 40  Total fertility rate represents the number of ...
# 41  Total fertility rate represents the number of ...
# 42  Total fertility rate represents the number of ...
# 43  Total fertility rate represents the number of ...
# 44  Total fertility rate represents the number of ...
# 45  Total fertility rate represents the number of ...
# 46  Total fertility rate represents the number of ...
# 47  Total fertility rate represents the number of ...
# 48  Total fertility rate represents the number of ...
# 49  Total fertility rate represents the number of ...
# 50  Total fertility rate represents the number of ...
# 51  Total fertility rate represents the number of ...
# 52  Total fertility rate represents the number of ...
# 53  Total fertility rate represents the number of ...

# %% [markdown]
# # CO2 emissions in the world

# %%
pd.read_sql(""" SELECT Indicators.*, Series.LongDefinition
                FROM Indicators
                LEFT JOIN Series 
                ON Indicators.IndicatorName  = Series.IndicatorName
                WHERE Indicators.IndicatorName LIKE 'CO2%'
                AND CountryName ='World'
                ORDER BY Year DESC
                LIMIT 10;""",
            conn)
