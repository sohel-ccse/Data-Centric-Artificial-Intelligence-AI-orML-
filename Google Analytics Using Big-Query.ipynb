# %% [markdown]
# # Environment Setup

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # First part
#
# Google Analytics data processing using BigQuery, Pandas and Matplotlib

# %%
import matplotlib.pyplot as plt
from google.cloud import bigquery 
import bq_helper
from bq_helper import BigQueryHelper

# %% [markdown]
# The connection to the BigQuery data source is established. First using the library BigQuery and after using the BigQueryHelper Library

# %%
#Using BigQuery
bq = bigquery.Client()

#Using BigQueryHelper
google_analytics = bq_helper.BigQueryHelper(active_project="bigquery-public-data", dataset_name="data:google_analytics_sample")
bqh = BigQueryHelper("bigquery-public-data", "google_analytics_sample")
# Out:
# Using Kaggle's public dataset BigQuery integration.
# Using Kaggle's public dataset BigQuery integration.
# Using Kaggle's public dataset BigQuery integration.

# %% [markdown]
# # Preliminary analysis
# The BigQuery dataset tables are listed. Only the first 3 tables are shown and the number of tables that are in the dataset.

# %%
#Listing
table_list = bqh.list_tables()

#Print the result. Note: Elements that are not string by string must be parsed in order to be represented. This is done by entering the element in the str() function.
print ('Number of tables: ' + str(len(table_list)) +  '\nFirst 5 tables: ' + str(table_list[0:5]))
# Out:
# Number of tables: 366
# First 5 tables: ['ga_sessions_20160801', 'ga_sessions_20160802', 'ga_sessions_20160803', 'ga_sessions_20160804', 'ga_sessions_20160805']

# %% [markdown]
# The first 10 rows of the first table in the list are examined

# %%
bqh.head(table_list[4], num_rows=10)
# Out:
#   visitorId  visitNumber     visitId  visitStartTime      date  \
# 0      None            1  1470384509      1470384509  20160805
# 1      None            1  1470440277      1470440277  20160805
# 2      None            1  1470420561      1470420561  20160805
# 3      None            1  1470449322      1470449322  20160805
# 4      None            1  1470383689      1470383689  20160805
# 5      None            1  1470465390      1470465390  20160805
# 6      None            3  1470427518      1470427518  20160805
# 7      None            1  1470448980      1470448980  20160805
# 8      None            4  1470448808      1470448808  20160805
# 9      None            4  1470450894      1470450894  20160805
#
#                                               totals  \
# 0  {'visits': 1, 'hits': 2, 'pageviews': 2, 'time...
# 1  {'visits': 1, 'hits': 2, 'pageviews': 2, 'time...
# 2  {'visits': 1, 'hits': 3, 'pageviews': 3, 'time...
# 3  {'visits': 1, 'hits': 3, 'pageviews': 3, 'time...
# 4  {'visits': 1, 'hits': 4, 'pageviews': 4, 'time...
# 5  {'visits': 1, 'hits': 4, 'pageviews': 3, 'time...
# 6  {'visits': 1, 'hits': 4, 'pageviews': 4, 'time...
# 7  {'visits': 1, 'hits': 4, 'pageviews': 4, 'time...
# 8  {'visits': 1, 'hits': 4, 'pageviews': 4, 'time...
# 9  {'visits': 1, 'hits': 4, 'pageviews': 4, 'time...
#
#                                        trafficSource  \
# 0  {'referralPath': None, 'campaign': '(not set)'...
# 1  {'referralPath': None, 'campaign': '(not set)'...
# 2  {'referralPath': None, 'campaign': '(not set)'...
# 3  {'referralPath': None, 'campaign': '(not set)'...
# 4  {'referralPath': None, 'campaign': '(not set)'...
# 5  {'referralPath': None, 'campaign': 'Data Share...
# 6  {'referralPath': None, 'campaign': '(not set)'...
# 7  {'referralPath': None, 'campaign': '(not set)'...
# 8  {'referralPath': None, 'campaign': '(not set)'...
# 9  {'referralPath': None, 'campaign': '(not set)'...
#
#                                               device  \
# 0  {'browser': 'Chrome', 'browserVersion': 'not a...
# 1  {'browser': 'Safari', 'browserVersion': 'not a...
# 2  {'browser': 'Chrome', 'browserVersion': 'not a...
# 3  {'browser': 'Chrome', 'browserVersion': 'not a...
# 4  {'browser': 'Safari', 'browserVersion': 'not a...
# 5  {'browser': 'Chrome', 'browserVersion': 'not a...
# 6  {'browser': 'Chrome', 'browserVersion': 'not a...
# 7  {'browser': 'Chrome', 'browserVersion': 'not a...
# 8  {'browser': 'Chrome', 'browserVersion': 'not a...
# 9  {'browser': 'Chrome', 'browserVersion': 'not a...
#
#                                           geoNetwork  \
# 0  {'continent': 'Asia', 'subContinent': 'Souther...
# 1  {'continent': 'Europe', 'subContinent': 'North...
# 2  {'continent': 'Americas', 'subContinent': 'Nor...
# 3  {'continent': 'Americas', 'subContinent': 'Nor...
# 4  {'continent': 'Europe', 'subContinent': 'North...
# 5  {'continent': 'Europe', 'subContinent': 'South...
# 6  {'continent': 'Europe', 'subContinent': 'North...
# 7  {'continent': 'Americas', 'subContinent': 'Nor...
# 8  {'continent': 'Americas', 'subContinent': 'Nor...
# 9  {'continent': 'Americas', 'subContinent': 'Nor...
#
#                            customDimensions  \
# 0           [{'index': 4, 'value': 'APAC'}]
# 1           [{'index': 4, 'value': 'EMEA'}]
# 2  [{'index': 4, 'value': 'North America'}]
# 3  [{'index': 4, 'value': 'North America'}]
# 4           [{'index': 4, 'value': 'EMEA'}]
# 5           [{'index': 4, 'value': 'EMEA'}]
# 6                                        []
# 7  [{'index': 4, 'value': 'North America'}]
# 8  [{'index': 4, 'value': 'North America'}]
# 9  [{'index': 4, 'value': 'North America'}]
#
#                                                 hits        fullVisitorId  \
# 0  [{'hitNumber': 1, 'time': 0, 'hour': 1, 'minut...  7443858563401308338
# 1  [{'hitNumber': 1, 'time': 0, 'hour': 16, 'minu...  7199058011591707522
# 2  [{'hitNumber': 1, 'time': 0, 'hour': 11, 'minu...  0971496584597288860
# 3  [{'hitNumber': 1, 'time': 0, 'hour': 19, 'minu...  9181275443615996946
# 4  [{'hitNumber': 1, 'time': 0, 'hour': 0, 'minut...  0533985195352177296
# 5  [{'hitNumber': 1, 'time': 0, 'hour': 23, 'minu...    49637949447489504
# 6  [{'hitNumber': 1, 'time': 0, 'hour': 13, 'minu...  0334862614244150114
# 7  [{'hitNumber': 1, 'time': 0, 'hour': 19, 'minu...  9131475862416280272
# 8  [{'hitNumber': 1, 'time': 0, 'hour': 19, 'minu...  5095003808516648444
# 9  [{'hitNumber': 1, 'time': 0, 'hour': 19, 'minu...  3089339005595914630
#
#   userId channelGrouping  socialEngagementType
# 0   None          Direct  Not Socially Engaged
# 1   None  Organic Search  Not Socially Engaged
# 2   None          Direct  Not Socially Engaged
# 3   None  Organic Search  Not Socially Engaged
# 4   None  Organic Search  Not Socially Engaged
# 5   None      Affiliates  Not Socially Engaged
# 6   None  Organic Search  Not Socially Engaged
# 7   None  Organic Search  Not Socially Engaged
# 8   None  Organic Search  Not Socially Engaged
# 9   None  Organic Search  Not Socially Engaged

# %% [markdown]
# # Highlights:
#
# 1. visitStartTime: is in a UNIX time format, that is, they are the second since midnight on 1 January 1970. This format is also known as the Unix Epoch or POSIX time.
# 1. The date is not formatted in dd-mm-yyyy format. That is, from 20160804 to 04-08-2016. The visitStartTime and date columns could be condensed. Resulting in a date and time format according to ISO 8601 (yyyy-MM-ddThh:mm:ss+00:00).
# 1. It would be convenient to analyze all the data from the columns that are in tuples (JSON), as they are: totals, trafficSource, device, geoNetwork, customDimensions and hits.
# 1. The table structure is analyzed using .table_schema() and referring to the first table in the list.

# %%
bqh.table_schema(table_list[4])
# Out:
# /src/bq-helper/bq_helper.py:63: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   'fields': pd.np.nan,
#                                   name     type      mode description
# 0                            visitorId  INTEGER  NULLABLE        None
# 1                          visitNumber  INTEGER  NULLABLE        None
# 2                              visitId  INTEGER  NULLABLE        None
# 3                       visitStartTime  INTEGER  NULLABLE        None
# 4                                 date   STRING  NULLABLE        None
# ..                                 ...      ...       ...         ...
# 331  hits.publisher_infos.dfpNetworkId   STRING  NULLABLE        None
# 332                      fullVisitorId   STRING  NULLABLE        None
# 333                             userId   STRING  NULLABLE        None
# 334                    channelGrouping   STRING  NULLABLE        None
# 335               socialEngagementType   STRING  NULLABLE        None
#
# [336 rows x 4 columns]

# %% [markdown]
# * The size of the data you are working with is displayed. This gives us a reference of the best way to work and the moment in which it is more optimal to dump the data in a Pandas DataFrame.
# *
# * SQL Syntax in BigQuery
# * VERY IMPORTANT: Avoid the SELECT FROM ...* due to the high computational (and economic) cost of this query More information about good practices in BigQuery prices.
# *
# * The size of the dataset is queried and divide the size in bytes by  230  to get the size in GB.

# %%
#The query to be executed
size_query = """
SELECT
    SUM(size_bytes) Bytes
FROM
    `bigquery-public-data.google_analytics_sample.__TABLES__`
"""

#Query execution and save the result in a data frame. The name of the colums of the dataset are defined in the query.
size_result = bq.query(size_query).to_dataframe()

print('The dataset size is ' + str(round(size_result.iloc[0]['Bytes']/(2**30),3)) + ' GB')
# Out:
# The dataset size is 5.371 GB

# %% [markdown]
# The entire dataset occupies several Gigabytes. As it is a dynamic dataset this size will change over time. Currently, (24/10/2020) the size is 5.371 GB.
#
# The attributes in JSON format are investigated. A query is made for this analysis

# %%
JSON_query = """
SELECT
    totals,
    trafficSource,
    device,
    geoNetwork,
    customDimensions,
    hits
FROM
    `bigquery-public-data.google_analytics_sample."""+ bqh.list_tables()[4] +"""`
LIMIT 1
"""
JSON_result = bq.query(JSON_query).to_dataframe()

print('totals: \n' +
str(JSON_result.iloc[0]['totals']) +
'\n\ntrafficSource: \n'+
str(JSON_result.iloc[0]['trafficSource'])+
'\n\ndevice: \n'+
str(JSON_result.iloc[0]['device']) +
'\n\ngeoNetwork: \n'+
str(JSON_result.iloc[0]['geoNetwork'])+
'\n\ncustomDimensions: \n'+
str(JSON_result.iloc[0]['customDimensions'])+
'\n\nhits: \n' +
str(JSON_result.iloc[0]['hits']))
# Out:
# totals:
# {'visits': 1, 'hits': 2, 'pageviews': 2, 'timeOnSite': 12, 'bounces': None, 'transactions': None, 'transactionRevenue': None, 'newVisits': 1, 'screenviews': None, 'uniqueScreenviews': None, 'timeOnScreen': None, 'totalTransactionRevenue': None, 'sessionQualityDim': None}
#
# trafficSource:
# {'referralPath': None, 'campaign': '(not set)', 'source': '(direct)', 'medium': '(none)', 'keyword': None, 'adContent': None, 'adwordsClickInfo': {'campaignId': None, 'adGroupId': None, 'creativeId': None, 'criteriaId': None, 'page': None, 'slot': None, 'criteriaParameters': 'not available in demo dataset', 'gclId': None, 'customerId': None, 'adNetworkType': None, 'targetingCriteria': None, 'isVideoAd': None}, 'isTrueDirect': True, 'campaignCode': None}
#
# device:
# {'browser': 'Chrome', 'browserVersion': 'not available in demo dataset', 'browserSize': 'not available in demo dataset', 'operatingSystem': 'Windows', 'operatingSystemVersion': 'not available in demo dataset', 'isMobile': False, 'mobileDeviceBranding': 'not available in demo dataset', 'mobileDeviceModel': 'not available in demo dataset', 'mobileInputSelector': 'not available in demo dataset', 'mobileDeviceInfo': 'not available in demo dataset', 'mobileDeviceMarketingName': 'not available in demo dataset', 'flashVersion': 'not available in demo dataset', 'javaEnabled': None, 'language': 'not available in demo dataset', 'screenColors': 'not available in demo dataset', 'screenResolution': 'not available in demo dataset', 'deviceCategory': 'desktop'}
#
# geoNetwork:
# {'continent': 'Asia', 'subContinent': 'Southern Asia', 'country': 'India', 'region': 'Karnataka', 'metro': '(not set)', 'city': 'Bengaluru', 'cityId': 'not available in demo dataset', 'networkDomain': 'aircel.co.in', 'latitude': 'not available in demo dataset', 'longitude': 'not available in demo dataset', 'networkLocation': 'not available in demo dataset'}
#
# customDimensions:
# [{'index': 4, 'value': 'APAC'}]
#
# hits:
# [{'hitNumber': 1, 'time': 0, 'hour': 1, 'minute': 8, 'isSecure': None, 'isInteraction': True, 'isEntrance': True, 'isExit': None, 'referer': None, 'page': {'pagePath': '/google+redesign/apparel/men++s', 'hostname': 'shop.googlemerchandisestore.com', 'pageTitle': "Men's", 'searchKeyword': None, 'searchCategory': None, 'pagePathLevel1': '/google+redesign/', 'pagePathLevel2': '/apparel/', 'pagePathLevel3': '/men++s', 'pagePathLevel4': ''}, 'transaction': {'transactionId': None, 'transactionRevenue': None, 'transactionTax': None, 'transactionShipping': None, 'affiliation': None, 'currencyCode': 'USD', 'localTransactionRevenue': None, 'localTransactionTax': None, 'localTransactionShipping': None, 'transactionCoupon': None}, 'item': {'transactionId': None, 'productName': None, 'productCategory': None, 'productSku': None, 'itemQuantity': None, 'itemRevenue': None, 'currencyCode': 'USD', 'localItemRevenue': None}, 'contentInfo': None, 'appInfo': {'name': None, 'version': None, 'id': None, 'installerId': None, 'appInstallerId': None, 'appName': None, 'appVersion': None, 'appId': None, 'screenName': 'shop.googlemerchandisestore.com/google+redesign/apparel/men++s', 'landingScreenName': 'shop.googlemerchandisestore.com/google+redesign/apparel/men++s', 'exitScreenName': 'shop.googlemerchandisestore.com/home', 'screenDepth': '0'}, 'exceptionInfo': {'description': None, 'isFatal': True, 'exceptions': None, 'fatalExceptions': None}, 'eventInfo': None, 'product': [{'productSKU': 'GGOEGAAX0104', 'v2ProductName': "Google Men's 100% Cotton Short Sleeve Hero Tee White", 'v2ProductCategory': "Home/Apparel/Men's/", 'productVariant': '(not set)', 'productBrand': '(not set)', 'productRevenue': None, 'localProductRevenue': None, 'productPrice': 16990000, 'localProductPrice': 16990000, 'productQuantity': None, 'productRefundAmount': None, 'localProductRefundAmount': None, 'isImpression': True, 'isClick': None, 'customDimensions': [], 'customMetrics': [], 'productListName': 'Category', 'productListPosition': 1}, {'productSKU': 'GGOEGAAX0105', 'v2ProductName': "Google Men's 100% Cotton Short Sleeve Hero Tee Black", 'v2ProductCategory': "Home/Apparel/Men's/", 'productVariant': '(not set)', 'productBrand': '(not set)', 'productRevenue': None, 'localProductRevenue': None, 'productPrice': 16990000, 'localProductPrice': 16990000, 'productQuantity': None, 'productRefundAmount': None, 'localProductRefundAmount': None, 'isImpression': True, 'isClick': None, 'customDimensions': [], 'customMetrics': [], 'productListName': 'Category', 'productListPosition': 2}, {'productSKU': 'GGOEGAAX0107', 'v2ProductName': "Google Men's 100% Cotton Short Sleeve Hero Tee Red", 'v2ProductCategory': "Home/Apparel/Men's/", 'productVariant': '(not set)', 'productBrand': '(not set)', 'productRevenue': None, 'localProductRevenue': None, 'productPrice': 16990000, 'localProductPrice': 16990000, 'productQuantity': None, 'productRefundAmount': None, 'localProductRefundAmount': None, 'isImpression': True, 'isClick': None, 'customDimensions': [], 'customMetrics': [], 'productListName': 'Category', 'productListPosition': 3}, {'productSKU': 'GGOEGAAX0106', 'v2ProductName': "Google Men's 100% Cotton Short Sleeve Hero Tee Navy", 'v2ProductCategory': "Home/Apparel/Men's/", 'productVariant': '(not set)', 'productBrand': '(not set)', 'productRevenue': None, 'localProductRevenue': None, 'productPrice': 16990000, 'localProductPrice': 16990000, 'productQuantity': None, 'productRefundAmount': None, 'localProductRefundAmount': None, 'isImpression': True, 'isClick': None, 'customDimensions': [], 'customMetrics': [], 'productListName': 'Category', 'productListPosition': 4}, {'productSKU': 'GGOEGAAX0340', 'v2ProductName': "Google Men's Vintage Badge Tee Green", 'v2ProductCategory': "Home/Apparel/Men's/", 'productVariant': '(not set)', 'productBrand': '(not set)', 'productRevenue': None, 'localProductRevenue': None, 'productPrice': 16990000, 'localProductPrice': 16990000, 'productQuantity': None, 'productRefu ...

# %% [markdown]
# # Information to collect
# 1. Visits per year: date attribute.
# 1. Visits per month: date attribute.
# 1. Visits by geographical area: geoNetwork attribute continent element.
# 1. Visits by country: geoNetwork attribute country element.
# 1. Visits by city in the country that you visit the most: geoNetwork attribute city element.
# 1. Social engagement: atributo socialEngagementType.
# 1. Channel grouping: channelGrouping attribute.
# 1. Browsers usegae: device attribute browser element.
# 1. OS usage: device attribute operatingSystem element.
# 1. Mobile device displays: device attribute operatingSystem element.

# %% [markdown]
# Analysis and visualization
# At this point, and knowing the data we have available, it starts to make the analysis of the data.
#
# 1. Visits per year
# 1.1. Querying and obtaining the dataset
# The SUBSTRING function will be used to "trim" the year. This function indicates the start and end position to be extracted.
#
# At first, this was done using the LEFT function, but it was not executed correctly, obtaining an error at the output (19/07/2020). I don't know the reason for this, but I know that this function is more recent than the SUBSTRING function, maybe because in the python library (google.cloud bigquery) it is still not correctly implemented.
#
# Otro hecho a destacar es el cambio de bigquery-public-data.google_analytics_sample.TABLE por *bigquery-public-data.google_analytics_sample.**. DOCUMENTATION.

# %%
year_query = """
SELECT substr(date,0,4) Year,
        COUNT(*) Visits
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
GROUP BY Year
"""
year_result = bq.query(year_query).to_dataframe()
year_result
# Out:
#    Year  Visits
# 0  2017  467260
# 1  2016  436393

# %% [markdown]
# # Visualization of the result

# %%
#The bar plot plot
year_graph = year_result.plot(kind='bar',x='Year',y='Visits')
#Title
year_graph.set_title('Visits per year')
#Removing the legend because does not add any important information
year_graph.legend().remove()
#Set the y and x axis labels
year_graph.set_ylabel('Visits')
year_graph.set_xlabel('Year')
plt.show()

# %% [markdown]
# # Visits per month

# %%
month_query = """
SELECT CONCAT(substr(date,0,4),'-', substr(date,5,2)) Month,
        COUNT(*) Visits
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
GROUP BY Month
ORDER BY Month
"""
month_result = bq.query(month_query).to_dataframe()
month_result
# Out:
#       Month  Visits
# 0   2016-08   74759
# 1   2016-09   71032
# 2   2016-10   97506
# 3   2016-11  113972
# 4   2016-12   79124
# 5   2017-01   64694
# 6   2017-02   62192
# 7   2017-03   69931
# 8   2017-04   67126
# 9   2017-05   65371
# 10  2017-06   63578
# 11  2017-07   71812
# 12  2017-08    2556

# %% [markdown]
# Visualization of the result for monthly

# %%
month_graph = month_result.plot(kind='line',x='Month',y='Visits')
month_graph.set_title('Visits per month')
month_graph.legend().remove()
month_graph.set_ylabel('Visits')
month_graph.set_xlabel('Month')
#Adding a grid in the plot for improve the visualization
month_graph.xaxis.grid(True, linestyle='-.', which='major', color='grey', alpha=.2)
month_graph.yaxis.grid(True, linestyle='-.', which='major', color='grey', alpha=.2)
plt.show()

# %% [markdown]
# # Visits by geographical area
#  Querying and obtaining the dataset
# In this query, the difficulty encountered is the extraction of the continent element within the JSON. To do this you simply have to join the attribute and subattribute with a point, i.e. geoNetwork.continent.

# %%
zone_query = """
SELECT geoNetwork.continent Area,
        COUNT(*) Visits
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
GROUP BY Area
ORDER BY Visits
"""
zone_result = bq.query(zone_query).to_dataframe()
zone_result
# Out:
#         Area  Visits
# 0  (not set)    1468
# 1     Africa   14745
# 2    Oceania   15054
# 3     Europe  198311
# 4       Asia  223698
# 5   Americas  450377

# %% [markdown]
# Visualization of the result

# %%
zone_graph = zone_result.plot(kind='bar',x='Area',y='Visits')
zone_graph.set_title('Visits per area')
zone_graph.legend().remove()
zone_graph.set_ylabel('Visits')
zone_graph.set_xlabel('Area')
plt.show()

# %% [markdown]
# # Visits per country
# Querying and obtaining the dataset

# %%
country_query = """
SELECT geoNetwork.country Country,
        COUNT(*) Visits
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
GROUP BY Country
ORDER BY Visits DESC
"""
country_result = bq.query(country_query).to_dataframe()
country_result
# Out:
#                  Country  Visits
# 0          United States  364744
# 1                  India   51140
# 2         United Kingdom   37393
# 3                 Canada   25869
# 4                Vietnam   24598
# ..                   ...     ...
# 217       American Samoa       1
# 218       St. Barthélemy       1
# 219       Norfolk Island       1
# 220  São Tomé & Príncipe       1
# 221              Eritrea       1
#
# [222 rows x 2 columns]

# %% [markdown]
# # Visualization of the result

# %%
country_graph = country_result.iloc[0:10].plot(kind='bar',x='Country',y='Visits')
country_graph.set_title('Visits per country')
country_graph.legend().remove()
country_graph.set_ylabel('Visits')
country_graph.set_xlabel('Country')
plt.show()

# %% [markdown]
# # Visits per city

# %%
city_query = """
SELECT geoNetwork.city City,
        COUNT(*) Visits
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
WHERE geoNetwork.country = (
    SELECT Country FROM ( 
        SELECT geoNetwork.country Country, COUNT(*) Visits 
            FROM 
                `bigquery-public-data.google_analytics_sample.*`
                GROUP BY Country ORDER BY Visits DESC) S LIMIT 1)
GROUP BY City
ORDER BY Visits DESC
"""
city_result = bq.query(city_query).to_dataframe()
city_result
# Out:
#                               City  Visits
# 0    not available in demo dataset  177760
# 1                    Mountain View   40659
# 2                         New York   26228
# 3                    San Francisco   20206
# 4                        Sunnyvale   13008
# ..                             ...     ...
# 251                      Abu Dhabi       1
# 252                    Mississauga       1
# 253                        Chennai       1
# 254                           Rome       1
# 255                       Yokohama       1
#
# [256 rows x 2 columns]

# %% [markdown]
# On the top the result is as expected, but on the bottom there is surprise, there are cities like Rome which obviously do not belong to the USA. In point 4.3, this anomaly in the data will be investigated in depth.
#
# 4.2. Visualization of the result
# The result is plotted on a bar chart. Because displaying such a high number of records (more than 200) would make the graph unreadable, we chose to show only the results from the second to the sixth (TOP 5).

# %%
city_graph = city_result.iloc[1:6].plot(kind='bar',x='City',y='Visits')
city_graph.set_title('Visits per city')
city_graph.legend().remove()
city_graph.set_ylabel('Visits')
city_graph.set_xlabel('City')
plt.show()

# %% [markdown]
# # Anomalies in the dataset

# %%
city_an_query = """
SELECT geoNetwork.city City,
        geoNetwork.country Country,
        COUNT(*) Visits
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
WHERE geoNetwork.country = (
    SELECT Country FROM ( 
        SELECT geoNetwork.country Country, COUNT(*) Visits 
            FROM 
                `bigquery-public-data.google_analytics_sample.*`
                GROUP BY Country ORDER BY Visits DESC) S LIMIT 1)
GROUP BY City, Country
ORDER BY Visits DESC
"""
city_an_result = bq.query(city_an_query).to_dataframe()
city_an_result
# Out:
#                               City        Country  Visits
# 0    not available in demo dataset  United States  177760
# 1                    Mountain View  United States   40659
# 2                         New York  United States   26228
# 3                    San Francisco  United States   20206
# 4                        Sunnyvale  United States   13008
# ..                             ...            ...     ...
# 251                       Brussels  United States       1
# 252                    Mississauga  United States       1
# 253                           Kyiv  United States       1
# 254                      Abu Dhabi  United States       1
# 255                       Yokohama  United States       1
#
# [256 rows x 3 columns]

# %% [markdown]
# As we have seen before, there is an anomaly and we can see that there is no relationship of integrity between cities and countries. You can see cities that don't belong to the United States.
#
# In the next query, we will return the cities that appear in more than one country.

# %%
city_country_an_query = """
SELECT  City,
        COUNT(*) CountCountry
        FROM (
            SELECT DISTINCT geoNetwork.city City, geoNetwork.country Country  
            FROM `bigquery-public-data.google_analytics_sample.*`
            )
GROUP BY City
HAVING CountCountry > 1
ORDER BY CountCountry DESC         
"""
city_country_an_result = bq.query(city_country_an_query).to_dataframe()

for i in range(city_country_an_result.shape[0]):
    print(str(city_country_an_result.iloc[i]['City']) + ' -> ' + str(city_country_an_result.iloc[i]['CountCountry']))
# Out:
# not available in demo dataset -> 201
# (not set) -> 170
# Mountain View -> 38
# San Francisco -> 32
# New York -> 28
# London -> 23
# San Jose -> 22
# Sunnyvale -> 16
# Los Angeles -> 16
# Paris -> 14
# Dublin -> 14
# Singapore -> 12
# Seattle -> 11
# Santa Clara -> 10
# Palo Alto -> 10
# Chicago -> 9
# Warsaw -> 9
# Sydney -> 8
# Hong Kong -> 7
# Ningbo -> 7
# Madrid -> 7
# Amsterdam -> 6
# Zurich -> 6
# Toronto -> 6
# Bengaluru -> 6
# Bangkok -> 6
# Istanbul -> 6
# Austin -> 6
# Kirkland -> 6
# Seoul -> 5
# Minato -> 5
# Vienna -> 5
# Munich -> 5
# Milan -> 5
# Jakarta -> 5
# Dubai -> 4
# Berlin -> 4
# Santiago -> 4
# Salem -> 4
# Osaka -> 4
# Bogota -> 4
# San Diego -> 4
# Tel Aviv-Yafo -> 4
# Rome -> 4
# San Bruno -> 4
# Washington -> 4
# Cambridge -> 4
# Houston -> 4
# Mumbai -> 4
# Chennai -> 3
# Stanford -> 3
# Dallas -> 3
# Redwood City -> 3
# Mexico City -> 3
# Ann Arbor -> 3
# Cupertino -> 3
# Hyderabad -> 3
# Kuala Lumpur -> 3
# Frankfurt -> 3
# Sao Paulo -> 3
# Tunis -> 3
# Buenos Aires -> 3
# New Delhi -> 3
# Prague -> 3
# San Mateo -> 3
# Barcelona -> 3
# Mississauga -> 3
# Shinjuku -> 3
# Hamburg -> 3
# Milpitas -> 3
# Nairobi -> 3
# Rio de Janeiro -> 2
# Dnipro -> 2
# Piscataway Township -> 2
# Brussels -> 2
# Boston -> 2
# Fremont -> 2
# Gurgaon -> 2
# Maracaibo -> 2
# Hanoi -> 2
# Jersey City -> 2
# Melbourne -> 2
# Plano -> 2
# Denver -> 2
# Moscow -> 2
# Manchester -> 2
# Oxford -> 2
# Yokohama -> 2
# Brisbane -> 2
# Kyiv -> 2
# Johor Bahru -> 2
# Ankara -> 2
# Ashburn -> 2
# Riyadh -> 2
# Pune -> 2
# Quezon City -> 2
# Atlanta -> 2
# Belo Horizonte -> 2
# Stockholm -> 2
# Ho Chi Minh City -> 2
# South San Francisco -> 2
# La Victoria -> 2
# Vancouver -> 2
# Kitchener -> 2
# Guadalajara -> 2
# Montreal -> 2
# Auckland -> 2
# Kiev -> 2
# Medellin -> 2
# Birmingham -> 2
# Manila -> 2
# Gothenburg -> 2
# Pittsburgh -> 2
# Saint Petersburg -> 2
# Abu Dhabi -> 2
# Krakow -> 2
# Miami -> 2
# Dundalk -> 2

# %% [markdown]
# To minimize these errors, a query could be made that includes the "correct list" of countries and cities. Assuming that the correct country containing that city is the one from which most visits have occurred. That is, the one that has the highest counter of the country/city relationship and the visits made.
#
# This is done by partitioning the data using the ROW_NUMBER function. The ROW_NUMBER function is chosen over other functions because of the way it manages ties.

# %%
city_country_test_query = """
    SELECT geoNetwork.city City, 
            geoNetwork.country Country,
            Count(*) Count, 
            ROW_NUMBER() OVER (PARTITION BY geoNetwork.city ORDER BY Count(*) DESC) AS row_num 
    FROM `bigquery-public-data.google_analytics_sample.*`
    GROUP BY Country, City
    ORDER BY City, row_num
"""
city_country_test_result = bq.query(city_country_test_query).to_dataframe()

for i in range(city_country_test_result.shape[0]):
    print(str(city_country_test_result.iloc[i]['City']) + ' -> ' + 
          str(city_country_test_result.iloc[i]['Country']) + 
          ' (RANKING: ' + str(city_country_test_result.iloc[i]['row_num']) + 
          ' COUNTER: ' + str(city_country_test_result.iloc[i]['Count']) + ')' )
# Out:
# 's Hertogenbosch -> Netherlands (RANKING: 1 COUNTER: 7)
# (not set) -> Taiwan (RANKING: 1 COUNTER: 7659)
# (not set) -> United States (RANKING: 2 COUNTER: 7195)
# (not set) -> Singapore (RANKING: 3 COUNTER: 3388)
# (not set) -> Thailand (RANKING: 4 COUNTER: 3138)
# (not set) -> India (RANKING: 5 COUNTER: 2276)
# (not set) -> (not set) (RANKING: 6 COUNTER: 1442)
# (not set) -> Bangladesh (RANKING: 7 COUNTER: 1359)
# (not set) -> Hong Kong (RANKING: 8 COUNTER: 915)
# (not set) -> Peru (RANKING: 9 COUNTER: 853)
# (not set) -> Vietnam (RANKING: 10 COUNTER: 522)
# (not set) -> Japan (RANKING: 11 COUNTER: 497)
# (not set) -> Greece (RANKING: 12 COUNTER: 486)
# (not set) -> Algeria (RANKING: 13 COUNTER: 347)
# (not set) -> Côte d’Ivoire (RANKING: 14 COUNTER: 263)
# (not set) -> United Kingdom (RANKING: 15 COUNTER: 261)
# (not set) -> Kosovo (RANKING: 16 COUNTER: 238)
# (not set) -> Dominican Republic (RANKING: 17 COUNTER: 208)
# (not set) -> Netherlands (RANKING: 18 COUNTER: 200)
# (not set) -> Jordan (RANKING: 19 COUNTER: 192)
# (not set) -> Palestine (RANKING: 20 COUNTER: 191)
# (not set) -> France (RANKING: 21 COUNTER: 127)
# (not set) -> Bosnia & Herzegovina (RANKING: 22 COUNTER: 126)
# (not set) -> Germany (RANKING: 23 COUNTER: 103)
# (not set) -> Iraq (RANKING: 24 COUNTER: 99)
# (not set) -> Albania (RANKING: 25 COUNTER: 92)
# (not set) -> Réunion (RANKING: 26 COUNTER: 91)
# (not set) -> Serbia (RANKING: 27 COUNTER: 81)
# (not set) -> Costa Rica (RANKING: 28 COUNTER: 81)
# (not set) -> Bolivia (RANKING: 29 COUNTER: 80)
# (not set) -> China (RANKING: 30 COUNTER: 77)
# (not set) -> Trinidad & Tobago (RANKING: 31 COUNTER: 72)
# (not set) -> Azerbaijan (RANKING: 32 COUNTER: 70)
# (not set) -> Sudan (RANKING: 33 COUNTER: 66)
# (not set) -> Congo - Kinshasa (RANKING: 34 COUNTER: 65)
# (not set) -> Macedonia (FYROM) (RANKING: 35 COUNTER: 64)
# (not set) -> Panama (RANKING: 36 COUNTER: 58)
# (not set) -> Lebanon (RANKING: 37 COUNTER: 46)
# (not set) -> Tunisia (RANKING: 38 COUNTER: 45)
# (not set) -> Philippines (RANKING: 39 COUNTER: 43)
# (not set) -> Cyprus (RANKING: 40 COUNTER: 40)
# (not set) -> Indonesia (RANKING: 41 COUNTER: 40)
# (not set) -> Ecuador (RANKING: 42 COUNTER: 38)
# (not set) -> Canada (RANKING: 43 COUNTER: 33)
# (not set) -> Iceland (RANKING: 44 COUNTER: 32)
# (not set) -> Curaçao (RANKING: 45 COUNTER: 30)
# (not set) -> Australia (RANKING: 46 COUNTER: 29)
# (not set) -> Mexico (RANKING: 47 COUNTER: 29)
# (not set) -> Maldives (RANKING: 48 COUNTER: 29)
# (not set) -> Switzerland (RANKING: 49 COUNTER: 29)
# (not set) -> Sweden (RANKING: 50 COUNTER: 28)
# (not set) -> Bahamas (RANKING: 51 COUNTER: 28)
# (not set) -> Oman (RANKING: 52 COUNTER: 28)
# (not set) -> Cameroon (RANKING: 53 COUNTER: 23)
# (not set) -> Afghanistan (RANKING: 54 COUNTER: 22)
# (not set) -> Iran (RANKING: 55 COUNTER: 20)
# (not set) -> Slovenia (RANKING: 56 COUNTER: 20)
# (not set) -> Libya (RANKING: 57 COUNTER: 20)
# (not set) -> Armenia (RANKING: 58 COUNTER: 20)
# (not set) -> Russia (RANKING: 59 COUNTER: 20)
# (not set) -> Norway (RANKING: 60 COUNTER: 19)
# (not set) -> Turkey (RANKING: 61 COUNTER: 19)
# (not set) -> Colombia (RANKING: 62 COUNTER: 17)
# (not set) -> Honduras (RANKING: 63 COUNTER: 14)
# (not set) -> South Korea (RANKING: 64 COUNTER: 14)
# (not set) -> St. Lucia (RANKING: 65 COUNTER: 14)
# (not set) -> Mayotte (RANKING: 66 COUNTER: 14)
# (not set) -> Malaysia (RANKING: 67 COUNTER: 12)
# (not set) -> Czechia (RANKING: 68 COUNTER: 12)
# (not set) -> Grenada (RANKING: 69 COUNTER: 12)
# (not set) -> Hungary (RANKING: 70 COUNTER: 12)
# (not set) -> Uruguay (RANKING: 71 COUNTER: 12)
# (not set) -> Aruba (RANKING: 72 COUNTER: 11)
# (not set) -> Spain (RANKING: 73 COUNTER: 11)
# (not set) -> Barbados (RANKING: 74 COUNTER: 11)
# (not set) -> Moldova (RANKING: 75 COUNTER: 11)
# (not set) -> Romania (RANKING: 76 COUNTER: 11)
# (not set) -> Guatemala (RANKING: 77 COUNTER: 11)
# (not set) -> Italy (RANKING: 78 COUNTER: 11)
# (not set) -> Northern Mariana Islands (RANKING: 79 COUNTER: 11)
# (not set) -> Malta (RANKING: 80 COUNTER: 10)
# (not set) -> Ethiopia (RANKING: 81 COUNTER: 10)
# (not set) -> St. Vincent & Grenadines (RANKING: 82 COUNTER: 9)
# (not set) -> Burundi (RANKING: 83 COUNTER: 9)
# (not set) -> Paraguay (RANKING: 84 COUNTER: 9)
# (not set) -> Luxembourg (RANKING: 85 COUNTER: 9)
# (not set) -> Cambodia (RANKING: 86 COUNTER: 9)
# (not set) -> Kazakhstan (RANKING: 87 COUNTER: 9)
# (not set) -> Kenya (RANKING: 88 COUNTER: 8)
# (not set) -> Turks & Caicos Islands (RANKING: 89 COUNTER: 8)
# (not set) -> Belize (RANKING: 90 COUNTER: 8)
# (not set) -> Denmark (RANKING: 91 COUNTER: 8)
# (not set) -> Sint Maarten (RANKING: 92 COUNTER: 8)
# (not set) -> Belgium (RANKING: 93 COUNTER: 8)
# (not set) -> Austria (RANKING: 94 COUNTER: 8)
# (not set) -> Kuwait (RANKING: 95 COUNTER: 7)
# (not set) -> Timor-Leste (RANKING: 96 COUNTER: 7)
# (not set) -> Mozambique (RANKING: 97 COUNTER: 7)
# (not set) -> Syria (RANKING: 98 COUNTER: 6)
# (not set) -> Georgia (RANKING: 99 COUNTER: 6)
# (not set) -> Somalia (RANKING: 100 COUNTER: 6)
# (not set) -> Djibouti (RANKING: 101 COUNTER: 6)
# (not set) -> Macau (RANKING: 102 COUNTER: 5)
# (not set) -> Mali (RANKING: 103 COUNTER: 5)
# (not set) -> Nepal (RANKING: 104 COUNTER: 5)
# (not set) -> Equatorial Guinea (RANKING: 105 COUNTER: 4)
# (not set) -> Poland (RANKING: 106 COUNTER: 4)
# (not set) -> Guadeloupe (RANKING: 107 COUNTER: 4)
# (not set) -> San Marino (RANKING: 108 COUNTER: 4)
# (not set) -> Pakistan (RANKING: 109 COUNTER: 4)
# (not set) -> Ukraine (RANKING: 110 COUNTER: 4)
# (not set) -> Caribbean Netherlands (RANKING: 111 COUNTER: 4)
# (not set) -> Guinea-Bissau (RANKING: 112 COUNTER: 4)
# (not set) -> Bermuda (RANKING: 113 COUNTER: 4)
# (not set) -> Brazil (RANKING: 114 COUNTER: 3)
# (not set) -> El Salvador (RANKING: 115 COUNTER: 3)
# (not set) -> Malawi (RANKING: 116 COUNTER: 3)
# (not set) -> Ghana (RANKING: 117 COUNTER: 3)
# (not set) -> French Polynesia (RANKING: 118 COUNTER: 3)
# (not set) -> Cook Islands (RANKING: 119 COUNTER: 3)
# (not set) -> Congo - Brazzaville (RANKING: 120 COUNTER: 3)
# (not set) -> Belarus (RANKING: 121 COUNTER: 3)
# (not set) -> Angola (RANKING: 122 COUNTER: 3)
# (not set) -> Martinique (RANKING: 123 COUNTER: 3)
# (not set) -> Rwanda (RANKING: 124 COUNTER: 3)
# (not set) -> Tanzania (RANKING: 125 COUNTER: 3)
# (not set) -> Seychelles (RANKING: 126 COUNTER: 3)
# (not set) -> Latvia (RANKING: 127 COUNTER: 3)
# (not set) -> St. Kitts & Nevis (RANKING: 128 COUNTER: 3)
# (not set) -> Morocco (RANKING: 129 COUNTER: 2)
# (not set) -> Andorra (RANKING: 130 COUNTER: 2)
# (not set) -> Guernsey (RANKING: 131 COUNTER: 2)
# (not set) -> Central African Republic (RANKING: 132 COUNTER: 2)
# (not set) -> Liberia (RANKING: 133 COUNTER: 2)
# (not set) -> Finland (RANKING: 134 COUNTER: 2)
# (not set) -> Botswana (RANKING: 135 COUNTER: 2)
# (not set) -> Yemen (RANKING: 136 COUNTER: 2)
# (not set) -> Uzbekistan (RANKING: 137 COUNTER: 2)
# (not set) -> Mongolia (RANKING: 138 COUNTER: 2)
# (not set) -> Saudi Arabia (RANKING: 139 COUNTER: 2)
# (not set) -> Kyrgyzstan (RANKING: 140 COUNTER: 2)
# (not set) -> Marshall Islands (RANKING: 141 COUNTER: 2)
# (not set) -> Qatar (RANKING: 142 COUNTER: 2)
# (not set) -> Sri Lanka (RANKING: 143 COUNTER: 2)
# (not set) -> Isle of Man (RANKING: 144 COUNTER: 2)
# (not set) -> Estonia (RANKING: 145 COUNTER: 1)
# (not set) -> Monaco (RANKING: 146 COUNTER: 1)
# (not set) -> Norfolk Island (RANKING: 147 COUNTER: 1)
# (not set) -> Åland Islands (RANKING: 148 COUNTER: 1)
# (not set) -> Venezuela (RANKING: 149 COUNTER: 1)
# (not set) -> Lithuania (RANKING: 150 COUNTER: 1)
# (not set) -> United Arab Emirates (RANKING: 151 COUNTER: 1)
# (not set) -> Fiji (RANKING: 152 COUNTER: 1)
# (not set) -> St. Martin (RANKING: 153 COUNTER: 1)
# (not set) -> St. Barthélemy (RANKING: 154 COUNTER: 1)
# (not set) -> Jamaica (RANKING: 155 COUNTER: 1)
# (not set) -> American Samoa (RANKING: 156 COUNTER: 1)
# (not set) -> Dominica (RANKING: 157 COUNTER: 1)
# (not set) -> Bhutan (RANKING: 158 COUNTER: 1)
# (not set) -> Anguilla (RANKING: 159 COUNTER: 1)
# (not set) -> Eritrea (RANKING: 160 COUNTER: 1)
# (not set) -> Uganda (RANKING: 161 COUNTER: 1)
# (not set) -> Madagascar (RANKING: 162 COUNTER: 1)
# (not set) -> Puerto Rico (RANKING: 163 COUNTER: 1)
# (not set) -> U.S. Virgin Islands (RANKING: 164 COUNTER: 1)
# (not set) -> Nicaragua (RANKING: 165 COUNTER: 1)
# (not set) -> Liechtenstein (RANKING: 166 COUNTER: 1)
# (not set) -> St. Pierre & Miquelon (RANKING: 167 COUNTER: 1)
# (not set) -> Israel (RANKING: 168 COUNTER: 1)
# (not set) -> Ireland (RANKING: 169 COUNTER: 1)
# (not set) -> Laos (RANKING: 170 COUNTER: 1)
# Aalborg -> Denmark (RANKING: 1 COUNTER: 41)
# Aalen -> Germany (RANKING: 1 COUNTER: 9)
# Aberdeen -> United Kingdom (RANKING: 1 COUNTER: 21)
# Abu Dhabi -> United Arab Emirates (RANKING: 1 COUNTER: 94)
# Abu Dhabi -> United States (RANKING: 2 COUNTER: 1)
# Adana -> Turkey (RANKING: 1 COUNTER: 188)
# Adelaide -> Australia (RANKING: 1 COUNTER: 18)
# Ahmedabad -> India (RANKING: 1 COUNTER: 916)
# Akron -> United States (RANKING: 1 COUNTER: 66)
# Alba -> Italy (RANKING: 1 COUNTER: 7)
# Alba Iulia -> Romania (RANKING: 1 COUNTER: 21)
# Alexandria -> Egypt (RANKING: 1 COUNTER: 52)
# Alicante -> Spain (RANKING: 1 COUNTER: 38)
# Allendale Charter Township -> United States (RANKING: 1 COUNTER: 8)
# Almaty -> Kazakhstan (RANKING: 1 COUNTER: 33)
# Almeria -> Spain (RANKING: 1 COUNTER: 33)
# Altrincham -> United Kingdom (RANKING: 1 COUNTER: 14)
# Amberg -> Germany (RANKING: 1 COUNTER: 30)
# Amersfoort -> Netherlands (RANKING: 1 COUNTER: 7)
# Amherst -> United States (RANKING: 1 COUNTER: 6)
# Amsterdam -> Netherlands (RANKING: 1 COUNTER: 1454)
# Amsterdam -> United States (RANKING: 2 COUNTER: 7)
# Amsterdam -> United Kingdom (RANKING: 3 COUNTER: 2)
# Amsterdam -> Ireland (RANKING: 4 COUNTER: 2)
# Amsterdam -> Germany (RANKING: 5 COUNTER: 1)
# Amsterdam -> Norway (RANKING: 6 COUNTER: 1)
# Amã -> Jordan (RANKING: 1 COUNTER: 84)
# Anaheim -> United States (RANKING: 1 COUNTER: 8)
# Ankara -> Turkey (RANKING: 1 COUNTER: 1510)
# Ankara -> Ireland (RANKING: 2 COUNTER: 1)
# Ann Arbor -> United States (RANKING: 1 COUNTER: 2238)
# Ann Arbor -> Ireland (RANKING: 2 COUNTER: 2)
# Ann Arbor -> France (RANKING: 3 COUNTER: 1)
# Annecy-le-Vieux -> France (RANKING: 1 COUNTER: 6)
# Antalya -> Turkey (RANKING: 1 COUNTER: 231)
# Antwerp -> Belgium (RANKING: 1 COUNTER: 17)
# Appleton -> United States (RANKING: 1 COUNTER: 12)
# Arequipa -> Peru (RANKING: 1 COUNTER: 17)
# Arnhem -> Netherlands (RANKING: 1 COUNTER: 6)
# Ashburn -> United States (RANKING: 1 COUNTER: 826)
# Ashburn -> China (RANKING: 2 COUNTER: 2)
# Asuncion -> Paraguay (RANKING: 1 COUNTER: 7)
# Athens -> Greece (RANKING: 1 COUNTER: 689)
# Atibaia -> Brazil (RANKING: 1 COUNTER: 7)
# Atlanta -> United States (RANKING: 1 COUNTER: 2350)
# Atlanta -> Puerto Rico (RANKING: 2 COUNTER: 2)
# Atwater -> United States (RANKING: 1 COUNTER: 8)
# Auckland -> New Zealand (RANKING: 1 COUNTER: 305)
# Auckland -> Australia (RANKING: 2 COUNTER: 1)
# Austin -> United States (RANKING: 1 COUNTER: 3782)
# Austin -> Ireland (RANKING: 2 COUNTER: 2)
# Austin -> Argentina (RANKING: 3 COUNTER: 2)
# Austin -> Brazil (RANKING: 4 COUNTER: 2)
# Austin -> South Africa (RANKING: 5 COUNTER: 1)
# Austin -> Israel (RANKING: 6 COUNTER: 1)
# Avon -> United States (RANKING: 1 COUNTER: 38)
# Aydin -> Turkey (RANKING: 1 COUNTER: 6)
# Baku -> Azerbaijan (RANKING: 1 COUNTER: 93)
# Ballinger -> United States (RANKING: 1 COUNTER: 10)
# Baltimore -> United States (RANKING: 1 COUNTER: 8)
# Bandung -> Indonesia (RANKING: 1 COUNTER: 372)
# Bangkok -> Thailand (RANKING: 1 COUNTER: 7681)
# Bangkok -> Singapore (RANKING: 2 COUNTER: 12)
# Bangkok -> United States (RANKING: 3 COUNTER: 11)
# Bangkok -> India (RANKING: 4 COUNTER: 2)
# Bangkok -> Hong Kong (RANKING: 5 COUNTER: 2)
# Bangkok -> Japan (RANKING: 6 COUNTER: 1)
# Barcelona -> Spain (RANKING: 1 COUNTER: 1388)
# Barcelona -> United States (RANKING: 2 COUNTER: 11)
# Barcelona -> Switzerland (RANKING: 3 COUNTER: 1)
# Barnsley -> United Kingdom (RANKING: 1 COUNTER: 6)
# Barranquilla -> Colombia (RANKING: 1 COUNTER: 8)
# Barrie -> Canada (RANKING: 1 COUNTER: 14)
# Bath -> United Kingdom (RANKING: 1 COUNTER: 7)
# Beijing -> China (RANKING: 1 COUNTER: 46)
# Beirut -> Lebanon (RANKING: 1 COUNTER: 6)
# Bekasi -> Indonesia (RANKING: 1 COUNTER: 13)
# Belagavi -> India (RANKING: 1 COUNTER: 8)
# Belgrade -> Serbia (RANKING: 1 COUNTER: 165)
# Bellevue -> United States (RANKING: 1 COUNTER: 30)
# Bellflower -> United States (RANKING: 1 COUNTER: 22)
# Bellingham -> United States (RANKING: 1 COUNTER: 29)
# Belo Horizonte -> Brazil (RANKING: 1 COUNTER: 265)
# Belo Horizonte -> United States (RANKING: 2 COUNTER: 2)
# Bengaluru -> India (RANKING: 1 COUNTER: 5436)
# Bengaluru -> United States (RANKING: 2 COUNTER: 25)
# Bengaluru -> Germany (RANKING: 3 COUNTER: 3)
# Bengaluru -> United Kingdom (RANKING: 4 COUNTER: 2)
# Bengaluru -> Singapore (RANKING: 5 COUNTER: 1)
# Bengaluru -> Taiwan (RANKING: 6 COUNTER: 1)
# Berkeley -> United States (RANKING: 1 COUNTER: 46)
# Berlin -> Germany (RANKING: 1 COUNTER: 1241)
# Berlin -> Finland (RANKING: 2 COUNTER: 1)
# Berlin -> Austria (RANKING: 3 COUNTER: 1)
# Berlin -> Switzerland (RANKING: 4 COUNTER: 1)
# Bhubaneswar -> India (RANKING: 1 COUNTER: 32)
# Bien Hoa -> Vietnam (RANKING: 1 COUNTER: 853)
# Bilbao -> Spain (RANKING: 1 COUNTER: 143)
# Birkenes -> Norway (RANKING: 1 COUNTER: 17)
# Birmingham -> United Kingdom (RANKING: 1 COUNTER: 49)
# Birmingham -> United States (RANKING: 2 COUNTER: 2)
# Boardman -> United States (RANKING: 1 COUNTER: 852)
# Bogota -> Colombia (RANKING: 1 COUNTER: 1631)
# Bogota -> United States (RANKING: 2 COUNTER: 2)
# Bogota -> El Salvador (RANKING: 3 COUNTER: 1)
# Bogota -> Spain (RANKING: 4 COUNTER: 1)
# Boise -> United States (RANKING: 1 COUNTER: 3)
# Bologna -> Italy (RANKING: 1 COUNTER: 20)
# Bordeaux -> France (RANKING: 1 COUNTER: 105)
# Boston -> United States (RANKING: 1 COUNTER: 966)
# Boston -> Hong Kong (RANKING: 2 COUNTER: 1)
# Bothell -> United States (RANKING: 1 COUNTER: 33)
# Boulder -> United States (RANKING: 1 COUNTER: 462)
# Bournemouth -> United Kingdom (RANKING: 1 COUNTER: 17)
# Bozeman -> United States (RANKING: 1 COUNTER: 3)
# Brampton -> Canada (RANKING: 1 COUNTER: 25)
# Brasilia -> Brazil (RANKING: 1 COUNTER: 177)
# Bratislava -> Slovakia (RANKING: 1 COUNTER: 66)
# Breda -> Netherlands (RANKING: 1 COUNTER: 44)
# Bremen -> Germany (RANKING: 1 COUNTER: 6)
# Brest -> Belarus (RANKING: 1 COUNTER: 34)
# Brisbane -> Australia (RANKING: 1 COUNTER: 855)
# Brisbane -> United States (RANKING: 2 COUNTER: 2)
# Bristol -> United Kingdom (RANKING: 1 COUNTER: 6)
# Brno -> Czechia (RANKING: 1 COUNTER: 42)
# Brookline -> United States (RANKING: 1 COUNTER: 6)
# Bruges -> Belgium (RANKING: 1 COUNTER: 19)
# Brussels -> Belgium (RANKING: 1 COUNTER: 227)
# Brussels -> United States (RANKING: 2 COUNTER: 1)
# Bucharest -> Romania (RANKING: 1 COUNTER: 1431)
# Budapest -> Hungary (RANKING: 1 COUNTER: 540)
# Buenos Aires -> Argentina (RANKING: 1 COUNTER: 1221)
# Buenos Aires -> United States (RANKING: 2 COUNTER: 4)
# Buenos Aires -> Brazil (RANKING: 3 COUNTER: 1)
# Buon Ma Thuot -> Vietnam (RANKING: 1 COUNTER: 157)
# Burlington -> United States (RANKING: 1 COUNTER: 10)
# Burnaby -> Canada (RANKING: 1 COUNTER: 159)
# Bursa -> Turkey (RANKING: 1 COUNTER: 378)
# Byron -> United States (RANKING: 1 COUNTER: 6)
# Cabimas -> Venezuela (RANKING: 1 COUNTER: 7)
# Cagliari -> Italy (RANKING: 1 COUNTER: 19)
# Cairo -> Egypt (RANKING: 1 COUNTER: 94)
# Calgary -> Canada (RANKING: 1 COUNTER: 216)
# Cali -> Colombia (RANKING: 1 COUNTER: 42)
# Cambridge -> United States (RANKING: 1 COUNTER: 1582)
# Cambridge -> Canada (RANKING: 2 COUNTER: 1)
# Cambridge -> Spain (RANKING: 3 COUNTER: 1)
# Cambridge -> Ireland (RANKING: 4 COUNTER: 1)
# Camden -> United States (RANKING: 1 COUNTER: 24)
# Campbell -> United States (RANKING: 1 COUNTER: 5)
# Campinas -> Brazil (RANKING: 1 COUNTER: 64)
# Can Tho -> Vietnam (RANKING: 1 COUNTER: 87)
# Cancun -> Mexico (RANKING: 1 COUNTER: 22)
# Canterbury -> United Kingdom (RANKING: 1 COUNTER: 63)
# Cao Lanh -> Vietnam (RANKING: 1 COUNTER: 12)
# Cape Town -> South Africa (RANKING: 1 COUNTER: 43)
# Caracas -> Venezuela (RANKING: 1 COUNTER: 19)
# Cardiff -> United Kingdom (RANKING: 1 COUNTER: 11)
# Carrollton -> United States (RANKING: 1 COUNTER: 6)
# Casablanca -> Morocco (RANKING: 1 COUNTER: 149)
# Cebu City -> Philippines (RANKING: 1 COUNTER: 507)
# Chambery -> France (RANKING: 1 COUNTER: 12)
# Chamblee -> United States (RANKING: 1 COUNTER: 18)
# Chandigarh -> India (RANKING: 1 COUNTER: 106)
# Charlotte -> United States (RANKING: 1 COUNTER: 510)
# Charlottesville -> United States (RANKING: 1 COUNTER: 13)
# Charlottetown -> Canada (RANKING: 1 COUNTER: 8)
# Chennai -> India (RANKING: 1 COUNTER: 4088)
# Chennai -> France (RANKING: 2 COUNTER: 1)
# Chennai -> United States (RANKING: 3 COUNTER: 1)
# Chevilly Larue -> France (RANKING: 1 COUNTER: 16)
# Chicago -> United States (RANKING: 1 COUNTER: 7430)
# Chicago -> Canada (RANKING: 2 COUNTER: 4)
# Chicago -> Ireland (RANKING: 3 COUNTER: 2)
# Chicago -> United Kingdom (RANKING: 4 COUNTER: 2)
# Chicago -> India (RANKING: 5 COUNTER: 2)
# Chicago -> Venezuela (RANKING: 6 COUNTER: 1)
# Chicago -> Denmark (RANKING: 7 COUNTER: 1)
# Chicago -> Germany (RANKING: 8 COUNTER: 1)
# Chicago -> Colombia (RANKING: 9 COUNTER: 1)
# Chico -> United States (RANKING: 1 COUNTER: 94)
# Chino -> United States (RANKING: 1 COUNTER: 11)
# Chisinau -> Moldova (RANKING: 1 COUNTER: 6)
# Chiyoda -> Japan (RANKING: 1 COUNTER: 65)
# Chuo -> Japan (RANKING: 1 COUNTER: 111)
# Cincinnati -> United States (RANKING: 1 COUNTER: 65)
# Ciudad Real -> Spain (RANKING: 1 COUNTER: 30)
# Clermont-Ferrand -> France (RANKING: 1 COUNTER: 6)
# Cluj-Napoca -> Romania (RANKING: 1 COUNTER: 103)
# Coffeyville -> United States (RANKING: 1 COUNTER: 45)
# Coimbatore -> India (RANKING: 1 COUNTER: 8)
# College Park -> United States (RANKING: 1 COUNTER: 13)
# Collegeville -> United States (RANKING: 1 COUNTER: 20)
# Cologne -> Germany (RANKING: 1 COUNTER: 73)
# Colombo -> Sri Lanka (RANKING: 1 COUNTER: 359)
# Columbia -> United States (RANKING: 1 COUNTER: 7)
# Columbus -> United States (RANKING: 1 COUNTER: 517)
# Copenhagen -> Denmark (RANKING: 1 COUNTER: 121)
# Cordoba -> Argentina (RANKING: 1 COUNTER: 42)
# Cork -> Ireland (RANKING: 1 COUNTER: 137)
# Council Bluffs -> United States (RANKING: 1 COUNTER: 95)
# Courbevoie -> France (RANKING: 1 COUNTER: 140)
# Coventry -> United Kingdom (RANKING: 1 COUNTER: 6)
# Cuiaba -> Brazil (RANKING: 1 COUNTER: 7)
# Culiacan -> Mexico (RANKING: 1 COUNTER: 20)
# Culpeper -> United States (RANKING: 1 COUNTER: 7)
# Cupertino -> United States (RANKING: 1 COUNTER: 665)
# Cupertino -> Australia (RANKING: 2 COUNTER: 1)
# Cupertino -> Japan (RANKING: 3 COUNTER: 1)
# Curitiba -> Brazil (RANKING: 1 COUNTER: 126)
# Cyberjaya -> Malaysia (RANKING: 1 COUNTER: 9)
# Da Nang -> Vietnam (RANKING: 1 COUNTER: 647)
# Dacun Township -> Taiwan (RANKING: 1 COUNTER: 14)
# Daegu -> South Korea (RANKING: 1 COUNTER: 8)
# Dahlonega -> United States (RANKING: 1 COUNTER: 17)
# Dalat -> Vietnam (RANKING: 1 COUNTER: 109)
# Dallas -> United States (RANKING: 1 COUNTER: 1832)
# Dallas -> United Arab Emirates (RANKING: 2 COUNTER: 1)
# Dallas -> Japan (RANKING: 3 COUNTER: 1)
# Daly City -> United States (RANKING: 1 COUNTER: 4)
# Danville -> United States (RANKING: 1 COUNTER: 16)
# Davao City -> Philippines (RANKING: 1 COUNTER: 51)
# Decin -> Czechia (RANKING: 1 COUNTER: 7)
# Deep River -> Canada (RANKING: 1 COUNTER: 5)
# Denver -> United States (RANKING: 1 COUNTER: 395)
# Denver -> Russia (RANKING: 2 COUNTER: 1)
# Depok -> Indonesia (RANKING: 1 COUNTER: 7)
# Detroit -> United States (RANKING: 1 COUNTER: 130)
# Deva -> Romania (RANKING: 1 COUNTER: 14)
# Dhaka -> Bangladesh (RANKING: 1 COUNTER: 7)
# Dnipro -> Ukraine (RANKING: 1 COUNTER: 21)
# Dnipro -> United States (RANKING: 2 COUNTER: 3)
# Doha -> Qatar (RANKING: 1 COUNTER: 30)
# Douglasville -> United States (RANKING: 1 COUNTER: 5)
# Druid Hills -> United States (RANKING: 1 COUNTER: 12)
# Dubai -> United Arab Emirates (RANKING: 1 COUNTER: 1058)
# Dubai -> United States (RANKING: 2 COUNTER: 4)
# Dubai -> Qatar (RANKING: 3 COUNTER: 1)
# Dubai -> Singapore (RANKING: 4 COUNTER: 1)
# Dublin -> Ireland (RANKING: 1 COUNTER: 4784)
# Dublin -> United States (RANKING: 2 COUNTER: 37)
# Dublin -> United Kingdom (RANKING: 3 COUNTER: 21)
# Dublin -> Austria (RANKING: 4 COUNTER: 9)
# Dublin -> Netherlands (RANKING: 5 COUNTER: 6)
# Dublin -> Poland (RANKING: 6 COUNTER: 6)
# Dublin -> Germany (RANKING: 7 COUNTER: 4)
# Dublin -> Spain (RANKING: 8 COUNTER: 3)
# Dublin -> United Arab Emirates (RANKING: 9 COUNTER: 2)
# Dublin -> France (RANKING: 10 COUNTER: 1)
# Dublin -> Italy (RANKING: 11 COUNTER: 1)
# Dublin -> Slovakia (RANKING: 12 COUNTER: 1)
# Dublin -> Australia (RANKING: 13 COUNTER: 1)
# Dublin -> Croatia (RANKING: 14 COUNTER: 1)
# Dundalk -> Ireland (RANKING: 1 COUNTER: 10)
# Dundalk -> United States (RANKING: 2 COUNTER: 9)
# Dusseldorf -> Germany (RANKING: 1 COUNTER: 42)
# East Lansing -> United States (RANKING: 1 COUNTER: 35)
# Eau Claire -> United States (RANKING: 1 COUNTER: 396)
# Edison -> United States (RANKING: 1 COUNTER: 11)
# Edmonton -> Canada (RANKING: 1 COUNTER: 38)
# Egham -> United Kingdom (RANKING: 1 COUNTER: 78)
# Eindhoven -> Netherlands (RANKING: 1 COUNTER: 7)
# El Paso -> United States (RANKING: 1 COUNTER: 33)
# Elche -> Spain (RANKING: 1 COUNTER: 16)
# Erode -> India (RANKING: 1 COUNTER: 370)
# Erzurum -> Turkey (RANKING: 1 COUNTER: 6)
# Esbjerg -> Denmark (RANKING: 1 COUNTER: 9)
# Eskisehir -> Turkey (RANKING: 1 COUNTER: 6)
# Evans -> United States (RANKING: 1 COUNTER: 7)
# Evanston -> United States (RANKING: 1 COUNTER: 125)
# Faisalabad -> Pakistan (RANKING: 1 COUNTER: 7)
# Fareham -> United Kingdom (RANKING: 1 COUNTER: 9)
# Farmington Hills -> United States (RANKING: 1 COUNTER: 16)
# Faro -> Portugal (RANKING: 1 COUNTER: 10)
# Florianopolis -> Brazil (RANKING: 1 COUNTER: 9)
# Forest Park -> United States (RANKING: 1 COUNTER: 12)
# Fort Collins -> United States (RANKING: 1 COUNTER: 7)
# Fort Worth -> United States (RANKING: 1 COUNTER: 12)
# Fortaleza -> Brazil (RANKING: 1 COUNTER: 25)
# Frankfurt -> Germany (RANKING: 1 COUNTER: 393)
# Frankfurt -> United Kingdom (RANKING: 2 COUNTER: 2)
# Frankfurt -> Poland (RANKING: 3 COUNTER: 1)
# Frederiksberg -> Denmark (RANKING: 1 COUNTER: 8)
# Fremont -> United States (RANKING: 1 COUNTER: 973)
# Fremont -> Hong Kong (RANKING: 2 COUNTER: 1)
# Fresno -> United States (RANKING: 1 COUNTER: 59)
# Fukui -> Japan (RANKING: 1 COUNTER: 17)
# Furth -> Germany (RANKING: 1 COUNTER: 7)
# Gatineau -> Canada (RANKING: 1 COUNTER: 8)
# Gaziantep -> Turkey (RANKING: 1 COUNTER: 24)
# Geneva -> Switzerland (RANKING: 1 COUNTER: 35)
# Ghent -> Belgium (RANKING: 1 COUNTER: 24)
# Gijon -> Spain (RANKING: 1 COUNTER: 22)
# Glasgow -> United Kingdom (RANKING: 1 COUNTER: 65)
# Goiania -> Brazil (RANKING: 1 COUNTER: 75)
# Goose Creek -> United States (RANKING: 1 COUNTER: 52)
# Gothenburg -> Sweden (RANKING: 1 COUNTER: 453)
# Gothenburg -> Denmark (RANKING: 2 COUNTER: 3)
# Granada -> Spain (RANKING: 1 COUNTER: 13)
# Greer -> United States (RANKING: 1 COUNTER: 16)
# Greve Strand -> Denmark (RANKING: 1 COUNTER: 7)
# Greystones -> Ireland (RANKING: 1 COUNTER: 7)
# Groningen -> Netherlands (RANKING: 1 COUNTER: 7)
# Guadalajara -> Mexico (RANKING: 1 COUNTER: 14)
# Guadalajara -> Spain (RANKING: 2 COUNTER: 10)
# Guangzhou -> China (RANKING: 1 COUNTER: 7)
# Guatemala City -> Guatemala (RANKING: 1 COUNTER: 24)
# Gurgaon -> India (RANKING: 1 COUNTER: 539)
# Gurgaon -> United States (RANKING: 2 COUNTER: 4)
# Guwahati -> India (RANKING: 1 COUNTER: 6)
# Ha Tinh -> Vietnam (RANKING: 1 COUNTER: 6)
# Hai Duong -> Vietnam (RANKING: 1 COUNTER: 142)
# Hai Phong -> Vietnam (RANKING: 1 COUNTER: 480)
# Hallein -> Austria (RANKING: 1 COUNTER: 15)
# Hamburg -> Germany (RANKING: 1 COUNTER: 833)
# Hamburg -> United States (RANKING: 2 COUNTER: 3)
# Hamburg -> United Kingdom (RANKING: 3 COUNTER: 1)
# Hamden -> United States (RANKING: 1 COUNTER: 23)
# Hangzhou -> China (RANKING: 1 COUNTER: 8)
# Hanoi -> Vietnam (RANKING: 1 COUNTER: 5031)
# Hanoi -> France (RANKING: 2 COUNTER: 1)
# Hayward -> United States (RANKING: 1 COUNTER: 19)
# Helsinki -> Finland (RANKING: 1 COUNTER: 45)
# Hermosillo -> Mexico (RANKING: 1 COUNTER: 6)
# Herzliya -> Israel (RANKING: 1 COUNTER: 6)
# Ho Chi Minh City -> Vietnam (RANKING: 1 COUNTER: 7341)
# Ho Chi Minh City -> United States (RANKING: 2 COUNTER: 1)
# Hoi An -> Vietnam (RANKING: 1 COUNTER: 41)
# Hong Kong -> Hong Kong (RANKING: 1 COUNTER: 3486)
# Hong Kong -> United States (RANKING: 2 COUNTER: 14)
# Hong Kong -> Taiwan (RANKING: 3 COUNTER: 3)
# Hong Kong -> China (RANKING: 4 COUNTER: 2)
# Hong Kong -> United Kingdom (RANKING: 5 COUNTER: 1)
# Hong Kong -> Japan (RANKING: 6 COUNTER: 1)
# Hong Kong -> Indonesia (RANKING: 7 COUNTER: 1)
# Honolulu -> United States (RANKING: 1 COUNTER: 21)
# Houston -> United States (RANKING: 1 COUNTER: 2471)
# Houston -> Germany (RANKING: 2 COUNTER: 2)
# Houston -> Turkey (RANKING: 3 COUNTER: 1)
# Houston -> Italy (RANKING: 4 COUNTER: 1)
# Hradec Kralove -> Czechia (RANKING: 1 COUNTER: 6)
# Hua Hin -> Thailand (RANKING: 1 COUNTER: 33)
# Hue -> Vietnam (RANKING: 1 COUNTER: 64)
# Hukou Township -> Taiwan (RANKING: 1 COUNTER: 16)
# Hyderabad -> India (RANKING: 1 COUNTER: 3915)
# Hyderabad -> United States (RANKING: 2 COUNTER: 17)
# Hyderabad -> United Arab Emirates (RANKING: 3 COUNTER: 2)
# Iasi -> Romania (RANKING: 1 COUNTER: 13)
# Indianapolis -> United States (RANKING: 1 COUNTER: 55)
# Indore -> India (RANKING: 1 COUNTER: 273)
# Ipoh -> Malaysia (RANKING: 1 COUNTER: 21)
# Irvine -> United States (RANKING: 1 COUNTER: 954)
# Islamabad -> Pakistan (RANKING: 1 COUNTER: 6)
# Issy-les-Moulineaux -> France (RANKING: 1 COUNTER: 19)
# Istanbul -> Turkey (RANKING: 1 COUNTER: 6319)
# Istanbul -> United States (RANKING: 2 COUNTER: 5)
# Istanbul -> Venezuela (RANKING: 3 COUNTER: 3)
# Istanbul -> Hungary (RANKING: 4 COUNTER: 1)
# Istanbul -> Spain (RANKING: 5 COUNTER: 1)
# Istanbul -> Italy (RANKING: 6 COUNTER: 1)
# Izmir -> Turkey (RANKING: 1 COUNTER: 1321)
# Jacksonville -> United States (RANKING: 1 COUNTER: 27)
# Jaipur -> India (RANKING: 1 COUNTER: 231)
# Jakarta -> Indonesia (RANKING: 1 COUNTER: 3312)
# Jakarta -> Singapore (RANKING: 2 COUNTER: 9)
# Jakarta -> Venezuela (RANKING: 3 COUNTER: 8)
# Jakarta -> United States (RANKING: 4 COUNTER: 8)
# Jakarta -> Australia (RANKING: 5 COUNTER: 1)
# Jeddah -> Saudi Arabia (RANKING: 1 COUNTER: 407)
# Jersey City -> United States (RANKING: 1 COUNTER: 255)
# Jersey City -> India (RANKING: 2 COUNTER: 1)
# Johnson City -> United States (RANKING: 1 COUNTER: 8)
# Johor Bahru -> Malaysia (RANKING: 1 COUNTER: 19)
# Johor Bahru -> Singapore (RANKING: 2 COUNTER: 1)
# Kalamazoo -> United States (RANKING: 1 COUNTER: 120)
# Kampar -> Malaysia (RANKING: 1 COUNTER: 112)
# Kansas City -> United States (RANKING: 1 COUNTER: 100)
# Karachi -> Pakistan (RANKING: 1 COUNTER: 415)
# Katowice -> Poland (RANKING: 1 COUNTER: 33)
# Kayseri -> Turkey (RANKING: 1 COUNTER: 39)
# Kharagpur -> India (RANKING: 1 COUNTER: 104)
# Kharkiv -> Ukraine (RANKING: 1 COUNTER: 42)
# Kiev -> Ukraine (RANKING: 1 COUNTER: 1273)
# Kiev -> Turkey (RANKING: 2 COUNTER: 1)
# Kirkland -> United States (RANKING: 1 COUNTER: 1968)
# Kirkland -> Italy (RANKING: 2 COUNTER: 2)
# Kirkland -> Germany (RANKING: 3 COUNTER: 1)
# Kirkland -> United Kingdom (RANKING: 4 COUNTER: 1)
# Kirkland -> Switzerland (RANKING: 5 COUNTER: 1)
# Kirkland -> South Korea (RANKING: 6 COUNTER: 1)
# Kiryat Ono -> Israel (RANKING: 1 COUNTER: 63)
# Kitchener -> Canada (RANKING: 1 COUNTER: 344)
# Kitchener -> United States (RANKING: 2 COUNTER: 3)
# Kochi -> India (RANKING: 1 COUNTER: 62)
# Kolkata -> India (RANKING: 1 COUNTER: 1736)
# Konya -> Turkey (RANKING: 1 COUNTER: 95)
# Kortrijk -> Belgium (RANKING: 1 COUNTER: 14)
# Kosice -> Slovakia (RANKING: 1 COUNTER: 16)
# Koszalin -> Poland (RANKING: 1 COUNTER: 8)
# Kovrov -> Russia (RANKING: 1 COUNTER: 8)
# Krakow -> Poland (RANKING: 1 COUNTER: 345)
# Krakow -> United States (RANKING: 2 COUNTER: 3)
# Kuala Lumpur -> Malaysia (RANKING: 1 COUNTER: 2232)
# Kuala Lumpur -> Singapore (RANKING: 2 COUNTER: 1)
# Kuala Lumpur -> Taiwan (RANKING: 3 COUNTER: 1)
# Kumamoto -> Japan (RANKING: 1 COUNTER: 5)
# Kuwait City -> Kuwait (RANKING: 1 COUNTER: 6)
# Kyiv -> Ukraine (RANKING: 1 COUNTER: 64)
# Kyiv -> United States (RANKING: 2 COUNTER: 1)
# La Chorrera -> Panama (RANKING: 1 COUNTER: 8)
# La Victoria -> Peru (RANKING: 1 COUNTER: 1788)
# La Victoria -> Argentina (RANKING: 2 COUNTER: 6)
# LaFayette -> United States (RANKING: 1 COUNTER: 6)
# Lagos -> Nigeria (RANKING: 1 COUNTER: 277)
# Laguna Beach -> United States (RANKING: 1 COUNTER: 225)
# Lahore -> Pakistan (RANKING: 1 COUNTER: 268)
# Lake Oswego -> United States (RANKING: 1 COUNTER: 183)
# Las Vegas -> United States (RANKING: 1 COUNTER: 69)
# Lausanne -> Switzerland (RANKING: 1 COUNTER: 17)
# Lawrence Township -> United States (RANKING: 1 COUNTER: 6)
# Leeds -> United Kingdom (RANKING: 1 COUNTER: 76)
# Lehi -> United States (RANKING: 1 COUNTER: 15)
# Leiria -> Portugal (RANKING: 1 COUNTER: 6)
# Lenoir -> United States (RANKING: 1 COUNTER: 15)
# Leon -> Mexico (RANKING: 1 COUNTER: 6)
# Leusden -> Netherlands (RANKING: 1 COUNTER: 19)
# Leuven -> Belgium (RANKING: 1 COUNTER: 8)
# Lewisville -> United States (RANKING: 1 COUNTER: 9)
# Lexington -> United States (RANKING: 1 COUNTER: 8)
# Lille -> France (RANKING: 1 COUNTER: 170)
# Lincoln -> United Kingdom (RANKING: 1 COUNTER: 6)
# Lisbon -> Portugal (RANKING: 1 COUNTER: 415)
# Liverpool -> United Kingdom (RANKING: 1 COUNTER: 46)
# Ljubljana -> Slovenia (RANKING: 1 COUNTER: 8)
# London -> United Kingdom (RANKING: 1 COUNTER: 12275)
# London -> Canada (RANKING: 2 COUNTER: 167)
# London -> United States (RANKING: 3 COUNTER: 97)
# London -> Ireland (RANKING: 4 COUNTER: 16)
# London -> Spain (RANKING: 5 COUNTER: 11)
# London -> Germany (RANKING: 6 COUNTER: 6)
# London -> France (RANKING: 7 COUNTER: 6)
# London -> Italy (RANKING: 8 COUNTER: 6)
# London -> Netherlands (RANKING: 9 COUNTER: 4)
# London -> Japan (RANKING: 10 COUNTER: 3)
# London -> Argentina (RANKING: 11 COUNTER: 2)
# London -> Sweden (RANKING: 12 COUNTER: 2)
# London -> Portugal (RANKING: 13 COUNTER: 2)
# London -> Singapore (RANKING: 14 COUNTER: 1)
# London -> Qatar (RANKING: 15 COUNTER: 1)
# London -> Switzerland (RANKING: 16 COUNTER: 1)
# London -> Saudi Arabia (RANKING: 17 COUNTER: 1)
# London -> Indonesia (RANKING: 18 COUNTER: 1)
# London -> Croatia (RANKING: 19 COUNTER: 1)
# London -> Greece (RANKING: 20 COUNTER: 1)
# London -> Poland (RANKING: 21 COUNTER: 1)
# London -> India (RANKING: 22 COUNTER: 1)
# London -> Belgium (RANKING: 23 COUNTER: 1)
# Longtan District -> Taiwan (RANKING: 1 COUNTER: 7)
# Los Angeles -> United States (RANKING: 1 COUNTER: 8637)
# Los Angeles -> India (RANKING: 2 COUNTER: 9)
# Los Angeles -> Japan (RANKING: 3 COUNTER: 4)
# Los Angeles -> Portugal (RANKING: 4 COUNTER: 3)
# Los Angeles -> United Kingdom (RANKING: 5 COUNTER: 2)
# Los Angeles -> Canada (RANKING: 6 COUNTER: 2)
# Los Angeles -> Sweden (RANKING: 7 COUNTER: 2)
# Los Angeles -> France (RANKING: 8 COUNTER: 2)
# Los Angeles -> United Arab Emirates (RANKING: 9 COUNTER: 2)
# Los Angeles -> Taiwan (RANKING: 10 COUNTER: 1)
# Los Angeles -> Russia (RANKING: 11 COUNTER: 1)
# Los Angeles -> Australia (RANKING: 12 COUNTER: 1)
# Los Angeles -> Hong Kong (RANKING: 13 COUNTER: 1)
# Los Angeles -> Venezuela (RANKING: 14 COUNTER: 1)
# Los Angeles -> Ukraine (RANKING: 15 COUNTER: 1)
# Los Angeles -> Brazil (RANKING: 16 COUNTER: 1)
# Los Gatos -> United States (RANKING: 1 COUNTER: 6)
# Louisville -> United States (RANKING: 1 COUNTER: 62)
# Lucknow -> India (RANKING: 1 COUNTER: 176)
# Ludhiana -> India (RANKING: 1 COUNTER: 9)
# Luxembourg City -> Luxembourg (RANKING: 1 COUNTER: 7)
# Lviv -> Ukraine (RANKING: 1 COUNTER: 6)
# Lyon -> France (RANKING: 1 COUNTER: 156)
# Madison -> United States (RANKING: 1 COUNTER: 17)
# Madrid -> Spain (RANKING: 1 COUNTER: 2577)
# Madrid -> United Kingdom (RANKING: 2 COUNTER: 6)
# Madrid -> Portugal (RANKING: 3 COUNTER: 4)
# Madrid -> United States (RANKING: 4 COUNTER: 3)
# Madrid -> Switzerland (RANKING: 5 COUNTER: 1)
# Madrid -> Dominican Republic (RANKING: 6 COUNTER: 1)
# Madrid -> Ireland (RANKING: 7 COUNTER: 1)
# Makassar -> Indonesia (RANKING: 1 COUNTER: 11)
# Makati -> Philippines (RANKING: 1 COUNTER: 345)
# Malaga -> Spain (RANKING: 1 COUNTER: 100)
# Manaus -> Brazil (RANKING: 1 COUNTER: 15)
# Manchester -> United Kingdom (RANKING: 1 COUNTER: 178)
# Manchester -> United States (RANKING: 2 COUNTER: 6)
# Manila -> Philippines (RANKING: 1 COUNTER: 249)
# Manila -> (not set) (RANKING: 2 COUNTER: 1)
# Mankato -> United States (RANKING: 1 COUNTER: 9)
# Mar del Plata -> Argentina (RANKING: 1 COUNTER: 14)
# Maracaibo -> Venezuela (RANKING: 1 COUNTER: 223)
# Maracaibo -> United States (RANKING: 2 COUNTER: 9)
# Marlboro -> United States (RANKING: 1 COUNTER: 6)
# Marseille -> France (RANKING: 1 COUNTER: 239)
# McAllen -> United States (RANKING: 1 COUNTER: 36)
# Mechelen -> Belgium (RANKING: 1 COUNTER: 33)
# Medan -> Indonesia (RANKING: 1 COUNTER: 20)
# Medellin -> Colombia (RANKING: 1 COUNTER: 138)
# Medellin -> United States (RANKING: 2 COUNTER: 2)
# Medina -> Saudi Arabia (RANKING: 1 COUNTER: 9)
# Melbourne -> Australia (RANKING: 1 COUNTER: 2731)
# Melbourne -> United States (RANKING: 2 COUNTER: 10)
# Memphis -> United States (RANKING: 1 COUNTER: 10)
# Menlo Park -> United States (RANKING: 1 COUNTER: 67)
# Mersin -> Turkey (RANKING: 1 COUNTER: 68)
# Metz -> France (RANKING: 1 COUNTER: 7)
# Mexico City -> Mexico (RANKING: 1 COUNTER: 2543)
# Mexico City -> United States (RANKING: 2 COUNTER: 11)
# Mexico City -> Argentina (RANKING: 3 COUNTER: 2)
# Miami -> United States (RANKING: 1 COUNTER: 153)
# Miami -> Mexico (RANKING: 2 COUNTER: 2)
# Miami Beach -> United States (RANKING: 1 COUNTER: 6)
# Milan -> Italy (RANKING: 1 COUNTER: 1229)
# Milan -> Brazil (RANKING: 2 COUNTER: 3)
# Milan -> United States (RANKING: 3 COUNTER: 1)
# Milan -> China (RANKING: 4 COUNTER: 1)
# Milan -> United Kingdom (RANKING: 5 COUNTER: 1)
# Milpitas -> United States (RANKING: 1 COUNTER: 603)
# Milpitas -> India (RANKING: 2 COUNTER: 1)
# Milpitas -> Canada (RANKING: 3 COUNTER: 1)
# Milwaukee -> United States (RANKING: 1 COUNTER: 7)
# Minato -> Japan (RANKING: 1 COUNTER: 2414)
# Minato -> United States (RANKING: 2 COUNTER: 15)
# Minato -> United Kingdom (RANKING: 3 COUNTER: 1)
# Minato -> Hong Kong (RANKING: 4 COUNTER: 1)
# Minato -> Singapore (RANKING: 5 COUNTER: 1)
# Minneapolis -> United States (RANKING: 1 COUNTER: 180)
# Minsk -> Belarus (RANKING: 1 COUNTER: 42)
# Minxiong Township -> Taiwan (RANKING: 1 COUNTER: 30)
# Mississauga -> Canada (RANKING: 1 COUNTER: 99)
# Mississauga -> United Kingdom (RANKING: 2 COUNTER: 2)
# Mississauga -> United States (RANKING: 3 COUNTER: 1)
# Miyazaki -> Japan (RANKING: 1 COUNTER: 11)
# Molesey -> United Kingdom (RANKING: 1 COUNTER: 44)
# Monterrey -> Mexico (RANKING: 1 COUNTER: 240)
# Montevideo -> Uruguay (RANKING: 1 COUNTER: 152)
# Montigny-le-Bretonneux -> France (RANKING: 1 COUNTER: 24)
# Montreal -> Canada (RANKING: 1 COUNTER: 2220)
# Montreal -> United States (RANKING: 2 COUNTER: 25)
# Montreuil -> France (RANKING: 1 COUNTER: 80)
# Moscow -> Russia (RANKING: 1 COUNTER: 2148)
# Moscow -> United Kingdom (RANKING: 2 COUNTER: 3)
# Mountain View -> United States (RANKING: 1 COUNTER: 40659)
# Mountain View -> Canada (RANKING: 2 COUNTER: 39)
# Mountain View -> United Kingdom (RANKING: 3 COUNTER: 25)
# Mountain View -> Taiwan (RANKING: 4 COUNTER: 21)
# Mountain View -> China (RANKING: 5 COUNTER: 14)
# Mountain View -> Germany (RANKING: 6 COUNTER: 13)
# Mountain View -> Singapore (RANKING: 7 COUNTER: 12)
# Mountain View -> India (RANKING: 8 COUNTER: 11)
# Mountain View -> Poland (RANKING: 9 COUNTER: 8)
# Mountain View -> Australia (RANKING: 10 COUNTER: 8)
# Mountain View -> Switzerland (RANKING: 11 COUNTER: 8)
# Mountain View -> Hong Kong (RANKING: 12 COUNTER: 7)
# Mountain View -> Japan (RANKING: 13 COUNTER: 7)
# Mountain View -> France (RANKING: 14 COUNTER: 6)
# Mountain View -> Brazil (RANKING: 15 COUNTER: 4)
# Mountain View -> Thailand (RANKING: 16 COUNTER: 4)
# Mountain View -> Turkey (RANKING: 17 COUNTER: 3)
# Mountain View -> Italy (RANKING: 18 COUNTER: 3)
# Mountain View -> Ireland (RANKING: 19 COUNTER: 3)
# Mountain View -> Sweden (RANKING: 20 COUNTER: 3)
# Mountain View -> Belgium (RANKING: 21 COUNTER: 3)
# Mountain View -> Philippines (RANKING: 22 COUNTER: 3)
# Mountain View -> Netherlands (RANKING: 23 COUNTER: 2)
# Mountain View -> Denmark (RANKING: 24 COUNTER: 2)
# Mountain View -> Guatemala (RANKING: 25 COUNTER: 2)
# Mountain View -> Slovakia (RANKING: 26 COUNTER: 2)
# Mountain View -> Serbia (RANKING: 27 COUNTER: 1)
# Mountain View -> Colombia (RANKING: 28 COUNTER: 1)
# Mountain View -> Mexico (RANKING: 29 COUNTER: 1)
# Mountain View -> Peru (RANKING: 30 COUNTER: 1)
# Mountain View -> Costa Rica (RANKING: 31 COUNTER: 1)
# Mountain View -> Guam (RANKING: 32 COUNTER: 1)
# Mountain View -> Israel (RANKING: 33 COUNTER: 1)
# Mountain View -> Puerto Rico (RANKING: 34 COUNTER: 1)
# Mountain View -> Kenya (RANKING: 35 COUNTER: 1)
# Mountain View -> Argentina (RANKING: 36 COUNTER: 1)
# Mountain View -> Dominican Republic (RANKING: 37 COUNTER: 1)
# Mountain View -> Spain (RANKING: 38 COUNTER: 1)
# Mueang Chiang Mai District -> Thailand (RANKING: 1 COUNTER: 184)
# Mueang Khon Kaen District -> Thailand (RANKING: 1 COUNTER: 293)
# Mueang Nakhon Ratchasima District -> Thailand (RANKING: 1 COUNTER: 15)
# Mueang Phitsanulok District -> Thailand (RANKING: 1 COUNTER: 6)
# Mueang Songkhla District -> Thailand (RANKING: 1 COUNTER: 22)
# Mumbai -> India (RANKING: 1 COUNTER: 4093)
# Mumbai -> United States (RANKING: 2 COUNTER: 3)
# Mumbai -> Singapore (RANKING: 3 COUNTER: 2)
# Mumbai -> Germany (RANKING: 4 COUNTER: 1)
# Munich -> Germany (RANKING: 1 COUNTER: 533)
# Munich -> Sweden (RANKING: 2 COUNTER: 3)
# Munich -> United States (RANKING: 3 COUNTER: 3)
# Munich -> Croatia (RANKING: 4 COUNTER: 1)
# Munich -> Austria (RANKING: 5 COUNTER: 1)
# Muntinlupa -> Philippines (RANKING: 1 COUNTER: 6)
# My Tho -> Vietnam (RANKING: 1 COUNTER: 92)
# Nagano -> Japan (RANKING: 1 COUNTER: 8)
# Nagoya -> Japan (RANKING: 1 COUNTER: 8)
# Naha -> Japan (RANKING: 1 COUNTER: 6)
# Nairobi -> Kenya (RANKING: 1 COUNTER: 147)
# Nairobi -> (not set) (RANKING: 2 COUNTER: 1)
# Nairobi -> Iceland (RANKING: 3 COUNTER: 1)
# Nakhon Pathom -> Thailand (RANKING: 1 COUNTER: 312)
# Nam Djinh -> Vietnam (RANKING: 1 COUNTER: 43)
# Nanded -> India (RANKING: 1 COUNTER: 7)
# Nantes -> France (RANKING: 1 COUNTER: 18)
# Naples -> Italy (RANKING: 1 COUNTER: 39)
# Nashville -> United States (RANKING: 1 COUNTER: 185)
# Navi Mumbai -> India (RANKING: 1 COUNTER: 58)
# Nea Erythraia -> Greece (RANKING: 1 COUNTER: 7)
# Neipu Township -> Taiwan (RANKING: 1 COUNTER: 20)
# Netanya -> Israel (RANKING: 1 COUNTER: 6)
# New Delhi -> India (RANKING: 1 COUNTER: 3203)
# New Delhi -> United States (RANKING: 2 COUNTER: 4)
# New Delhi -> Brazil (RANKING: 3 COUNTER: 2)
# New Orleans -> United States (RANKING: 1 COUNTER: 7)
# New Westminster -> Canada (RANKING: 1 COUNTER: 6)
# New York -> United States (RANKING: 1 COUNTER: 26228)
# New York -> Canada (RANKING: 2 COUNTER: 61)
# New York -> India (RANKING: 3 COUNTER: 9)
# New York -> Switzerland (RANKING: 4 COUNTER: 8)
# New York -> United Kingdom (RANKING: 5 COUNTER: 8)
# New York -> China (RANKING: 6 COUNTER: 6)
# New York -> Vietnam (RANKING: 7 COUNTER: 6)
# New York -> France (RANKING: 8 COUNTER: 5)
# New York -> Spain (RANKING: 9 COUNTER: 5)
# New York -> Germany (RANKING: 10 COUNTER: 4)
# New York -> Israel (RANKING: 11 COUNTER: 3)
# New York -> Kuwait (RANKING: 12 COUNTER: 2)
# New York -> Brazil (RANKING: 13 COUNTER: 2)
# New York -> Argentina (RANKING: 14 COUNTER: 2)
# New York -> Sri Lanka (RANKING: 15 COUNTER: 2)
# New York -> (not set) (RANKING: 16 COUNTER: 2)
# New York -> Taiwan (RANKING: 17 COUNTER: 2)
# New York -> Venezuela (RANKING: 18 COUNTER: 2)
# New York -> Mexico (RANKING: 19 COUNTER: 2)
# New York -> Australia (RANKING: 20 COUNTER: 2)
# New York -> Poland (RANKING: 21 COUNTER: 2)
# New York -> Sweden (RANKING: 22 COUNTER: 2)
# New York -> Cyprus (RANKING: 23 COUNTER: 1)
# New York -> Portugal (RANKING: 24 COUNTER: 1)
# New York -> Nicaragua (RANKING: 25 COUNTER: 1)
# New York -> Lebanon (RANKING: 26 COUNTER: 1)
# New York -> Italy (RANKING: 27 COUNTER: 1)
# New York -> South Africa (RANKING: 28 COUNTER: 1)
# Newark -> United States (RANKING: 1 COUNTER: 6)
# Newtonville -> United States (RANKING: 1 COUNTER: 19)
# Nha Trang -> Vietnam (RANKING: 1 COUNTER: 101)
# Nice -> France (RANKING: 1 COUNTER: 25)
# Ningbo -> China (RANKING: 1 COUNTER: 189)
# Ningbo -> Japan (RANKING: 2 COUNTER: 2)
# Ningbo -> United States (RANKING: 3 COUNTER: 2)
# Ningbo -> United Kingdom (RANKING: 4 COUNTER: 2)
# Ningbo -> Germany (RANKING: 5 COUNTER: 1)
# Ningbo -> Taiwan (RANKING: 6 COUNTER: 1)
# Ningbo -> (not set) (RANKING: 7 COUNTER: 1)
# Noida -> India (RANKING: 1 COUNTER: 66)
# Norfolk -> United States (RANKING: 1 COUNTER: 26)
# Normandy -> United States (RANKING: 1 COUNTER: 13)
# North Attleborough -> United States (RANKING: 1 COUNTER: 6)
# North Richland Hills -> United States (RANKING: 1 COUNTER: 11)
# Nottingham -> United Kingdom (RANKING: 1 COUNTER: 14)
# Nuremberg -> Germany (RANKING: 1 COUNTER: 7)
# Oakland -> United States (RANKING: 1 COUNTER: 342)
# Odense -> Denmark (RANKING: 1 COUNTER: 35)
# Odessa -> Ukraine (RANKING: 1 COUNTER: 25)
# Oegstgeest -> Netherlands (RANKING: 1 COUNTER: 11)
# Okemos -> United States (RANKING: 1 COUNTER: 12)
# Olomouc -> Czechia (RANKING: 1 COUNTER: 12)
# Omaha -> United States (RANKING: 1 COUNTER: 34)
# Oneonta -> United States (RANKING: 1 COUNTER: 23)
# Oradea -> Romania (RANKING: 1 COUNTER: 24)
# Orem -> United States (RANKING: 1 COUNTER: 6)
# Orlando -> United States (RANKING: 1 COUNTER: 242)
# Osaka -> Japan (RANKING: 1 COUNTER: 749)
# Osaka -> Thailand (RANKING: 2 COUNTER: 2)
# Osaka -> United States (RANKING: 3 COUNTER: 1)
# Osaka -> (not set) (RANKING: 4 COUNTER: 1)
# Oshkosh -> United States (RANKING: 1 COUNTER: 72)
# Osijek -> Croatia (RANKING: 1 COUNTER: 26)
# Oslo -> Norway (RANKING: 1 COUNTER: 94)
# Ostrava -> Czechia (RANKING: 1 COUNTER: 7)
# Ottawa -> Canada (RANKING: 1 COUNTER: 76)
# Oude Meer -> Netherlands (RANKING: 1 COUNTER: 56)
# Overland Park -> United States (RANKING: 1 COUNTER: 17)
# Oviedo -> United States (RANKING: 1 COUNTER: 118)
# Oxford -> United Kingdom (RANKING: 1 COUNTER: 56)
# Oxford -> United States (RANKING: 2 COUNTER: 6)
# Padua -> Italy (RANKING: 1 COUNTER: 25)
# Palo Alto -> United States (RANKING: 1 COUNTER: 2871)
# Palo Alto -> Taiwan (RANKING: 2 COUNTER: 4)
# Palo Alto -> India (RANKING: 3 COUNTER: 3)
# Palo Alto -> Ireland (RANKING: 4 COUNTER: 2)
# Palo Alto -> Canada (RANKING: 5 COUNTER: 1)
# Palo Alto -> Denmark (RANKING: 6 COUNTER: 1)
# Palo Alto -> Germany (RANKING: 7 COUNTER: 1)
# Palo Alto -> Hong Kong (RANKING: 8 COUNTER: 1)
# Palo Alto -> Sweden (RANKING: 9 COUNTER: 1)
# Palo Alto -> Singapore (RANKING: 10 COUNTER: 1)
# Panama City -> United States (RANKING: 1 COUNTER: 8)
# Paradise -> United States (RANKING: 1 COUNTER: 7)
# Paris -> France (RANKING: 1 COUNTER: 3964)
# Paris -> United States (RANKING: 2 COUNTER: 27)
# Paris -> Germany (RANKING: 3 COUNTER: 5)
# Paris -> United Kingdom (RANKING: 4 COUNTER: 4)
# Paris -> Switzerland (RANKING: 5 COUNTER: 2)
# Paris -> Netherlands (RANKING: 6 COUNTER: 2)
# Paris -> Italy (RANKING: 7 COUNTER: 2)
# Paris -> Poland (RANKING: 8 COUNTER: 1)
# Paris -> Canada (RANKING: 9 COUNTER: 1)
# Paris -> Greece (RANKING: 10 COUNTER: 1)
# Paris -> Monaco (RANKING: 11 COUNTER: 1)
# Paris -> Denmark (RANKING: 12 COUNTER: 1)
# Paris -> Ireland (RANKING: 13 COUNTER: 1)
# Paris -> Réunion (RANKING: 14 COUNTER: 1)
# Parma -> Italy (RANKING: 1 COUNTER: 8)
# Parsippany-Troy Hills -> United States (RANKING: 1 COUNTER: 8)
# Pasig -> Philippines (RANKING: 1 COUNTER: 13)
# Patna -> India (RANKING: 1 COUNTER: 57)
# Perth -> Australia (RANKING: 1 COUNTER: 107)
# Pescara -> Italy (RANKING: 1 COUNTER: 6)
# Pessac -> France (RANKING: 1 COUNTER: 19)
# Petaling Jaya -> Malaysia (RANKING: 1 COUNTER: 151)
# Petergof -> Russia (RANKING: 1 COUNTER: 12)
# Phan Thiet -> Vietnam (RANKING: 1 COUNTER: 7)
# Philadelphia -> United States (RANKING: 1 COUNTER: 744)
# Phnom Penh -> Cambodia (RANKING: 1 COUNTER: 7)
# Phoenix -> United States (RANKING: 1 COUNTER: 421)
# Pinamar -> Argentina (RANKING: 1 COUNTER: 7)
# Piscataway Township -> United States (RANKING: 1 COUNTER: 164)
# Piscataway Township -> Netherlands (RANKING: 2 COUNTER: 1)
# Pittsburgh -> United States (RANKING: 1 COUNTER: 1075)
# Pittsburgh -> Ireland (RANKING: 2 COUNTER: 1)
# Piura -> Peru (RANKING: 1 COUNTER: 13)
# Plano -> United States (RANKING: 1 COUNTER: 26)
# Plano -> United Kingdom (RANKING: 2 COUNTER: 1)
# Pleasanton -> United States (RANKING: 1 COUNTER: 20)
# Pleiku -> Vietnam (RANKING: 1 COUNTER: 12)
# Pontivy -> France (RANKING: 1 COUNTER: 13)
# Portland -> United States (RANKING: 1 COUNTER: 247)
# Porto Alegre -> Brazil (RANKING: 1 COUNTER: 97)
# Poznan -> Poland (RANKING: 1 COUNTER: 196)
# Pozuelo de Alarcon -> Spain (RANKING: 1 COUNTER: 300)
# Prague -> Czechia (RANKING: 1 COUNTER: 601)
# Prague -> United States (RANKING: 2 COUNTER: 2)
# Prague -> Israel (RANKING: 3 COUNTER: 1)
# Prato -> Italy (RANKING: 1 COUNTER: 20)
# Pryor -> United States (RANKING: 1 COUNTER: 6)
# Pueblo -> United States (RANKING: 1 COUNTER: 16)
# Pune -> India (RANKING: 1 COUNTER: 2012)
# Pune -> United States (RANKING: 2 COUNTER: 2)
# Quang Ngai -> Vietnam (RANKING: 1 COUNTER: 12)
# Quebec City -> Canada (RANKING: 1 COUNTER: 314)
# Quezon City -> Philippines (RANKING: 1 COUNTER: 1234)
# Quezon City -> India (RANKING: 2 COUNTER: 1)
# Qui Nhon -> Vietnam (RANKING: 1 COUNTER: 41)
# Quimper -> France (RANKING: 1 COUNTER: 32)
# Quito -> Ecuador (RANKING: 1 COUNTER: 17)
# Rach Gia -> Vietnam (RANKING: 1 COUNTER: 26)
# Raleigh -> United States (RANKING: 1 COUNTER: 55)
# Ramat Gan -> Israel (RANKING: 1 COUNTER: 22)
# Randburg -> South Africa (RANKING: 1 COUNTER: 9)
# Recife -> Brazil (RANKING: 1 COUNTER: 8)
# Redmond -> United States (RANKING: 1 COUNTER: 551)
# Redondo Beach -> United States (RANKING: 1 COUNTER: 7)
# Redwood City -> United States (RANKING: 1 COUNTER: 296)
# Redwood City -> Ireland (RANKING: 2 COUNTER: 2)
# Redwood City -> Canada (RANKING: 3 COUNTER: 1)
# Reims -> France (RANKING: 1 COUNTER: 11)
# Rexburg -> United States (RANKING: 1 COUNTER: 59)
# Ribeirao Preto -> Brazil (RANKING: 1 COUNTER: 12)
# Richardson -> United States (RANKING: 1 COUNTER: 58)
# Ridgewood -> United States (RANKING: 1 COUNTER: 75)
# Riga -> Latvia (RANKING: 1 COUNTER: 58)
# Rio de Janeiro -> Brazil (RANKING: 1 COUNTER: 628)
# Rio de Janeiro -> United States (RANKING: 2 COUNTER: 7)
# Rishon LeTsiyon -> Israel (RANKING: 1 COUNTER: 6)
# Riverside -> United States (RANKING: 1 COUNTER: 15)
# Riyadh -> Saudi Arabia (RANKING: 1 COUNTER: 636)
# Riyadh -> Netherlands (RANKING: 2 COUNTER: 1)
# Rockwood -> United States (RANKING: 1 COUNTER: 14)
# Rome -> Italy (RANKING: 1 COUNTER: 514)
# Rome -> Czechia (RANKING: 2 COUNTER: 1)
# Rome -> Romania (RANKING: 3 COUNTER: 1)
# Rome -> United States (RANKING: 4 COUNTER: 1)
# Rosario -> Argentina (RANKING: 1 COUNTER: 37)
# Roskilde -> Denmark (RANKING: 1 COUNTER: 16)
# Rotterdam -> Netherlands (RANKING: 1 COUNTER: 100)
# Rzeszow -> Poland (RANKING: 1 COUNTER: 9)
# Sabadell -> Spain (RANKING: 1 COUNTER: 7)
# Sacramento -> United States (RANKING: 1 COUNTER: 62)
# Saint Paul -> United States (RANKING: 1 COUNTER: 17)
# Saint Petersburg -> Russia (RANKING: 1 COUNTER: 218)
# Saint Petersburg -> Georgia (RANKING: 2 COUNTER: 3)
# Saint Polten -> Austria (RANKING: 1 COUNTER: 30)
# Saint-Ouen-l'Aumone -> France (RANKING: 1 COUNTER: 9)
# Sakai -> Japan (RANKING: 1 COUNTER: 26)
# Salem -> United States (RANKING: 1 COUNTER: 2224)
# Salem -> Costa Rica (RANKING: 2 COUNTER: 1)
# Salem -> Mexico (RANKING: 3 COUNTER: 1)
# Salem -> Canada (RANKING: 4 COUNTER: 1)
# Salford -> United Kingdom (RANKING: 1 COUNTER: 33)
# Salt Lake City -> United States (RANKING: 1 COUNTER: 35)
# Salvador -> Brazil (RANKING: 1 COUNTER: 42)
# Salzburg -> Austria (RANKING: 1 COUNTER: 14)
# Samsun -> Turkey (RANKING: 1 COUNTER: 29)
# San Antonio -> United States (RANKING: 1 COUNTER: 393)
# San Bruno -> United States (RANKING: 1 COUNTER: 1680)
# San Bruno -> India (RANKING: 2 COUNTER: 4)
# San Bruno -> Nigeria (RANKING: 3 COUNTER: 1)
# San Bruno -> Chile (RANKING: 4 COUNTER: 1)
# San Carlos -> United States (RANKING: 1 COUNTER: 9)
# San Diego -> United States (RANKING: 1 COUNTER: 1332)
# San Diego -> China (RANKING: 2 COUNTER: 2)
# San Diego -> South Africa (RANKING: 3 COUNTER: 1)
# San Diego -> Hong Kong (RANKING: 4 COUNTER: 1)
# San Francisco -> United States (RANKING: 1 COUNTER: 20206)
# San Francisco -> Taiwan (RANKING: 2 COUNTER: 22)
# San Francisco -> Canada (RANKING: 3 COUNTER: 20)
# San Francisco -> Japan (RANKING: 4 COUNTER: 11)
# San Francisco -> India (RANKING: 5 COUNTER: 11)
# San Francisco -> Australia (RANKING: 6 COUNTER: 7)
# San Francisco -> Ireland (RANKING: 7 COUNTER: 6)
# San Francisco -> United Kingdom (RANKING: 8 COUNTER: 5)
# San Francisco -> France (RANKING: 9 COUNTER: 5)
# San Francisco -> Sweden (RANKING: 10 COUNTER: 4)
# San Francisco -> Mexico (RANKING: 11 COUNTER: 3)
# San Francisco -> Philippines (RANKING: 12 COUNTER: 3)
# San Francisco -> Hong Kong (RANKING: 13 COUNTER: 2)
# San Francisco -> South Korea (RANKING: 14 COUNTER: 2)
# ...
# Warsaw -> Lithuania (RANKING: 7 COUNTER: 1)
# Warsaw -> Georgia (RANKING: 8 COUNTER: 1)
# Warsaw -> Denmark (RANKING: 9 COUNTER: 1)
# Washington -> United States (RANKING: 1 COUNTER: 2529)
# Washington -> Switzerland (RANKING: 2 COUNTER: 1)
# Washington -> India (RANKING: 3 COUNTER: 1)
# Washington -> United Arab Emirates (RANKING: 4 COUNTER: 1)
# Waterloo -> Canada (RANKING: 1 COUNTER: 41)
# Watford -> United Kingdom (RANKING: 1 COUNTER: 6)
# Weingarten -> Germany (RANKING: 1 COUNTER: 13)
# Wellesley -> United States (RANKING: 1 COUNTER: 60)
# Wellington -> New Zealand (RANKING: 1 COUNTER: 19)
# Westlake Village -> United States (RANKING: 1 COUNTER: 23)
# Westville -> South Africa (RANKING: 1 COUNTER: 8)
# Wheaton -> United States (RANKING: 1 COUNTER: 16)
# Wheeling -> United States (RANKING: 1 COUNTER: 14)
# White Plains -> United States (RANKING: 1 COUNTER: 7)
# Whitewater -> United States (RANKING: 1 COUNTER: 32)
# Winnipeg -> Canada (RANKING: 1 COUNTER: 6)
# Wollongong -> Australia (RANKING: 1 COUNTER: 6)
# Woodbridge Township -> United States (RANKING: 1 COUNTER: 12)
# Wrexham -> United Kingdom (RANKING: 1 COUNTER: 9)
# Wroclaw -> Poland (RANKING: 1 COUNTER: 126)
# Yokohama -> Japan (RANKING: 1 COUNTER: 324)
# Yokohama -> United States (RANKING: 2 COUNTER: 1)
# Zagreb -> Croatia (RANKING: 1 COUNTER: 247)
# Zamudio -> Spain (RANKING: 1 COUNTER: 14)
# Zaoqiao Township -> Taiwan (RANKING: 1 COUNTER: 7)
# Zapopan -> Mexico (RANKING: 1 COUNTER: 6)
# Zaragoza -> Spain (RANKING: 1 COUNTER: 43)
# Zaventem -> Belgium (RANKING: 1 COUNTER: 9)
# Zhongli District -> Taiwan (RANKING: 1 COUNTER: 240)
# Zhudong Township -> Taiwan (RANKING: 1 COUNTER: 17)
# Zurich -> Switzerland (RANKING: 1 COUNTER: 1171)
# Zurich -> United States (RANKING: 2 COUNTER: 8)
# Zurich -> Germany (RANKING: 3 COUNTER: 2)
# Zurich -> Netherlands (RANKING: 4 COUNTER: 2)
# Zurich -> United Kingdom (RANKING: 5 COUNTER: 2)
# Zurich -> Ireland (RANKING: 6 COUNTER: 1)
# Zwolle -> Netherlands (RANKING: 1 COUNTER: 6)
# not available in demo dataset -> United States (RANKING: 1 COUNTER: 177760)
# not available in demo dataset -> United Kingdom (RANKING: 2 COUNTER: 23908)
# not available in demo dataset -> India (RANKING: 3 COUNTER: 21256)
# not available in demo dataset -> Germany (RANKING: 4 COUNTER: 16566)
# not available in demo dataset -> Canada (RANKING: 5 COUNTER: 16262)
# not available in demo dataset -> Japan (RANKING: 6 COUNTER: 14702)
# not available in demo dataset -> Brazil (RANKING: 7 COUNTER: 14111)
# not available in demo dataset -> France (RANKING: 8 COUNTER: 10470)
# not available in demo dataset -> Mexico (RANKING: 9 COUNTER: 10292)
# not available in demo dataset -> Turkey (RANKING: 10 COUNTER: 10251)
# not available in demo dataset -> Netherlands (RANKING: 11 COUNTER: 9385)
# not available in demo dataset -> Italy (RANKING: 12 COUNTER: 9374)
# not available in demo dataset -> Russia (RANKING: 13 COUNTER: 9234)
# not available in demo dataset -> Thailand (RANKING: 14 COUNTER: 8422)
# not available in demo dataset -> Vietnam (RANKING: 15 COUNTER: 8160)
# not available in demo dataset -> Spain (RANKING: 16 COUNTER: 6767)
# not available in demo dataset -> Philippines (RANKING: 17 COUNTER: 6437)
# not available in demo dataset -> Poland (RANKING: 18 COUNTER: 5660)
# not available in demo dataset -> Indonesia (RANKING: 19 COUNTER: 5242)
# not available in demo dataset -> Taiwan (RANKING: 20 COUNTER: 4903)
# not available in demo dataset -> Romania (RANKING: 21 COUNTER: 4731)
# not available in demo dataset -> Ukraine (RANKING: 22 COUNTER: 4139)
# not available in demo dataset -> Belgium (RANKING: 23 COUNTER: 4079)
# not available in demo dataset -> Australia (RANKING: 24 COUNTER: 4027)
# not available in demo dataset -> Malaysia (RANKING: 25 COUNTER: 3782)
# not available in demo dataset -> Sweden (RANKING: 26 COUNTER: 3701)
# not available in demo dataset -> Argentina (RANKING: 27 COUNTER: 3573)
# not available in demo dataset -> Czechia (RANKING: 28 COUNTER: 3558)
# not available in demo dataset -> China (RANKING: 29 COUNTER: 3443)
# not available in demo dataset -> Pakistan (RANKING: 30 COUNTER: 3310)
# not available in demo dataset -> Switzerland (RANKING: 31 COUNTER: 3146)
# not available in demo dataset -> Colombia (RANKING: 32 COUNTER: 3041)
# not available in demo dataset -> Denmark (RANKING: 33 COUNTER: 3038)
# not available in demo dataset -> South Korea (RANKING: 34 COUNTER: 2842)
# not available in demo dataset -> Peru (RANKING: 35 COUNTER: 2830)
# not available in demo dataset -> Egypt (RANKING: 36 COUNTER: 2197)
# not available in demo dataset -> Greece (RANKING: 37 COUNTER: 2152)
# not available in demo dataset -> Norway (RANKING: 38 COUNTER: 2119)
# not available in demo dataset -> Austria (RANKING: 39 COUNTER: 2104)
# not available in demo dataset -> Saudi Arabia (RANKING: 40 COUNTER: 2077)
# not available in demo dataset -> South Africa (RANKING: 41 COUNTER: 2029)
# not available in demo dataset -> Hungary (RANKING: 42 COUNTER: 1960)
# not available in demo dataset -> United Arab Emirates (RANKING: 43 COUNTER: 1945)
# not available in demo dataset -> Portugal (RANKING: 44 COUNTER: 1934)
# not available in demo dataset -> Israel (RANKING: 45 COUNTER: 1917)
# not available in demo dataset -> Venezuela (RANKING: 46 COUNTER: 1867)
# not available in demo dataset -> New Zealand (RANKING: 47 COUNTER: 1865)
# not available in demo dataset -> Morocco (RANKING: 48 COUNTER: 1756)
# not available in demo dataset -> Algeria (RANKING: 49 COUNTER: 1708)
# not available in demo dataset -> Slovakia (RANKING: 50 COUNTER: 1702)
# not available in demo dataset -> Bulgaria (RANKING: 51 COUNTER: 1668)
# not available in demo dataset -> Serbia (RANKING: 52 COUNTER: 1625)
# not available in demo dataset -> Chile (RANKING: 53 COUNTER: 1526)
# not available in demo dataset -> Ireland (RANKING: 54 COUNTER: 1497)
# not available in demo dataset -> Ecuador (RANKING: 55 COUNTER: 1196)
# not available in demo dataset -> Nigeria (RANKING: 56 COUNTER: 1167)
# not available in demo dataset -> Croatia (RANKING: 57 COUNTER: 1120)
# not available in demo dataset -> Sri Lanka (RANKING: 58 COUNTER: 1105)
# not available in demo dataset -> Bangladesh (RANKING: 59 COUNTER: 931)
# not available in demo dataset -> Kazakhstan (RANKING: 60 COUNTER: 926)
# not available in demo dataset -> Finland (RANKING: 61 COUNTER: 903)
# not available in demo dataset -> Belarus (RANKING: 62 COUNTER: 897)
# not available in demo dataset -> Lithuania (RANKING: 63 COUNTER: 804)
# not available in demo dataset -> Bosnia & Herzegovina (RANKING: 64 COUNTER: 777)
# not available in demo dataset -> Puerto Rico (RANKING: 65 COUNTER: 727)
# not available in demo dataset -> Dominican Republic (RANKING: 66 COUNTER: 724)
# not available in demo dataset -> Slovenia (RANKING: 67 COUNTER: 700)
# not available in demo dataset -> Macedonia (FYROM) (RANKING: 68 COUNTER: 692)
# not available in demo dataset -> Georgia (RANKING: 69 COUNTER: 660)
# not available in demo dataset -> Latvia (RANKING: 70 COUNTER: 644)
# not available in demo dataset -> Estonia (RANKING: 71 COUNTER: 632)
# not available in demo dataset -> Kenya (RANKING: 72 COUNTER: 615)
# not available in demo dataset -> Iraq (RANKING: 73 COUNTER: 599)
# not available in demo dataset -> Jordan (RANKING: 74 COUNTER: 583)
# not available in demo dataset -> Guatemala (RANKING: 75 COUNTER: 544)
# not available in demo dataset -> Cambodia (RANKING: 76 COUNTER: 506)
# not available in demo dataset -> Kuwait (RANKING: 77 COUNTER: 506)
# not available in demo dataset -> Qatar (RANKING: 78 COUNTER: 501)
# not available in demo dataset -> Singapore (RANKING: 79 COUNTER: 478)
# not available in demo dataset -> Costa Rica (RANKING: 80 COUNTER: 471)
# not available in demo dataset -> Tunisia (RANKING: 81 COUNTER: 468)
# not available in demo dataset -> Uruguay (RANKING: 82 COUNTER: 463)
# not available in demo dataset -> Albania (RANKING: 83 COUNTER: 424)
# not available in demo dataset -> Cyprus (RANKING: 84 COUNTER: 422)
# not available in demo dataset -> Panama (RANKING: 85 COUNTER: 409)
# not available in demo dataset -> Azerbaijan (RANKING: 86 COUNTER: 406)
# not available in demo dataset -> El Salvador (RANKING: 87 COUNTER: 384)
# not available in demo dataset -> Ghana (RANKING: 88 COUNTER: 378)
# not available in demo dataset -> Lebanon (RANKING: 89 COUNTER: 345)
# not available in demo dataset -> Moldova (RANKING: 90 COUNTER: 302)
# not available in demo dataset -> Hong Kong (RANKING: 91 COUNTER: 291)
# not available in demo dataset -> Oman (RANKING: 92 COUNTER: 277)
# not available in demo dataset -> Armenia (RANKING: 93 COUNTER: 260)
# not available in demo dataset -> Tanzania (RANKING: 94 COUNTER: 257)
# not available in demo dataset -> Bahrain (RANKING: 95 COUNTER: 256)
# not available in demo dataset -> Bolivia (RANKING: 96 COUNTER: 238)
# not available in demo dataset -> Mongolia (RANKING: 97 COUNTER: 233)
# not available in demo dataset -> Nepal (RANKING: 98 COUNTER: 206)
# not available in demo dataset -> Kosovo (RANKING: 99 COUNTER: 197)
# not available in demo dataset -> Myanmar (Burma) (RANKING: 100 COUNTER: 196)
# not available in demo dataset -> Honduras (RANKING: 101 COUNTER: 174)
# not available in demo dataset -> Uganda (RANKING: 102 COUNTER: 165)
# not available in demo dataset -> Malta (RANKING: 103 COUNTER: 165)
# not available in demo dataset -> Laos (RANKING: 104 COUNTER: 160)
# not available in demo dataset -> Cameroon (RANKING: 105 COUNTER: 152)
# not available in demo dataset -> Jamaica (RANKING: 106 COUNTER: 152)
# not available in demo dataset -> Senegal (RANKING: 107 COUNTER: 151)
# not available in demo dataset -> Luxembourg (RANKING: 108 COUNTER: 140)
# not available in demo dataset -> Nicaragua (RANKING: 109 COUNTER: 137)
# not available in demo dataset -> Kyrgyzstan (RANKING: 110 COUNTER: 132)
# not available in demo dataset -> Ethiopia (RANKING: 111 COUNTER: 129)
# not available in demo dataset -> Paraguay (RANKING: 112 COUNTER: 116)
# not available in demo dataset -> Montenegro (RANKING: 113 COUNTER: 110)
# not available in demo dataset -> Macau (RANKING: 114 COUNTER: 110)
# not available in demo dataset -> Iceland (RANKING: 115 COUNTER: 107)
# not available in demo dataset -> Uzbekistan (RANKING: 116 COUNTER: 94)
# not available in demo dataset -> Yemen (RANKING: 117 COUNTER: 94)
# not available in demo dataset -> Trinidad & Tobago (RANKING: 118 COUNTER: 92)
# not available in demo dataset -> Mauritius (RANKING: 119 COUNTER: 87)
# not available in demo dataset -> Libya (RANKING: 120 COUNTER: 72)
# not available in demo dataset -> Mozambique (RANKING: 121 COUNTER: 67)
# not available in demo dataset -> Brunei (RANKING: 122 COUNTER: 65)
# not available in demo dataset -> Maldives (RANKING: 123 COUNTER: 60)
# not available in demo dataset -> Zimbabwe (RANKING: 124 COUNTER: 59)
# not available in demo dataset -> Martinique (RANKING: 125 COUNTER: 58)
# not available in demo dataset -> Côte d’Ivoire (RANKING: 126 COUNTER: 57)
# not available in demo dataset -> Angola (RANKING: 127 COUNTER: 55)
# not available in demo dataset -> Réunion (RANKING: 128 COUNTER: 53)
# not available in demo dataset -> Madagascar (RANKING: 129 COUNTER: 46)
# not available in demo dataset -> Barbados (RANKING: 130 COUNTER: 44)
# not available in demo dataset -> Rwanda (RANKING: 131 COUNTER: 43)
# not available in demo dataset -> Fiji (RANKING: 132 COUNTER: 43)
# not available in demo dataset -> Benin (RANKING: 133 COUNTER: 42)
# not available in demo dataset -> Jersey (RANKING: 134 COUNTER: 41)
# not available in demo dataset -> Guam (RANKING: 135 COUNTER: 40)
# not available in demo dataset -> Mauritania (RANKING: 136 COUNTER: 40)
# not available in demo dataset -> Zambia (RANKING: 137 COUNTER: 40)
# not available in demo dataset -> Congo - Kinshasa (RANKING: 138 COUNTER: 38)
# not available in demo dataset -> Haiti (RANKING: 139 COUNTER: 37)
# not available in demo dataset -> Burkina Faso (RANKING: 140 COUNTER: 37)
# not available in demo dataset -> Namibia (RANKING: 141 COUNTER: 36)
# not available in demo dataset -> Afghanistan (RANKING: 142 COUNTER: 35)
# not available in demo dataset -> Bermuda (RANKING: 143 COUNTER: 34)
# not available in demo dataset -> Somalia (RANKING: 144 COUNTER: 33)
# not available in demo dataset -> Togo (RANKING: 145 COUNTER: 32)
# not available in demo dataset -> Guinea (RANKING: 146 COUNTER: 31)
# not available in demo dataset -> Mali (RANKING: 147 COUNTER: 30)
# not available in demo dataset -> Suriname (RANKING: 148 COUNTER: 30)
# not available in demo dataset -> Guyana (RANKING: 149 COUNTER: 27)
# not available in demo dataset -> Sudan (RANKING: 150 COUNTER: 26)
# not available in demo dataset -> Guadeloupe (RANKING: 151 COUNTER: 25)
# not available in demo dataset -> Gabon (RANKING: 152 COUNTER: 25)
# not available in demo dataset -> Guernsey (RANKING: 153 COUNTER: 23)
# not available in demo dataset -> New Caledonia (RANKING: 154 COUNTER: 23)
# not available in demo dataset -> Iran (RANKING: 155 COUNTER: 21)
# not available in demo dataset -> U.S. Virgin Islands (RANKING: 156 COUNTER: 21)
# not available in demo dataset -> Chad (RANKING: 157 COUNTER: 20)
# not available in demo dataset -> Monaco (RANKING: 158 COUNTER: 19)
# not available in demo dataset -> Belize (RANKING: 159 COUNTER: 19)
# not available in demo dataset -> Faroe Islands (RANKING: 160 COUNTER: 18)
# not available in demo dataset -> French Guiana (RANKING: 161 COUNTER: 18)
# not available in demo dataset -> Aruba (RANKING: 162 COUNTER: 18)
# not available in demo dataset -> Cape Verde (RANKING: 163 COUNTER: 18)
# not available in demo dataset -> (not set) (RANKING: 164 COUNTER: 18)
# not available in demo dataset -> French Polynesia (RANKING: 165 COUNTER: 17)
# not available in demo dataset -> Andorra (RANKING: 166 COUNTER: 15)
# not available in demo dataset -> Cayman Islands (RANKING: 167 COUNTER: 14)
# not available in demo dataset -> Swaziland (RANKING: 168 COUNTER: 14)
# not available in demo dataset -> Tajikistan (RANKING: 169 COUNTER: 12)
# not available in demo dataset -> Bahamas (RANKING: 170 COUNTER: 12)
# not available in demo dataset -> Botswana (RANKING: 171 COUNTER: 12)
# not available in demo dataset -> Papua New Guinea (RANKING: 172 COUNTER: 11)
# not available in demo dataset -> Niger (RANKING: 173 COUNTER: 10)
# not available in demo dataset -> Gibraltar (RANKING: 174 COUNTER: 10)
# not available in demo dataset -> St. Lucia (RANKING: 175 COUNTER: 10)
# not available in demo dataset -> Gambia (RANKING: 176 COUNTER: 10)
# not available in demo dataset -> Grenada (RANKING: 177 COUNTER: 10)
# not available in demo dataset -> Malawi (RANKING: 178 COUNTER: 9)
# not available in demo dataset -> Sierra Leone (RANKING: 179 COUNTER: 8)
# not available in demo dataset -> Bhutan (RANKING: 180 COUNTER: 7)
# not available in demo dataset -> Liechtenstein (RANKING: 181 COUNTER: 6)
# not available in demo dataset -> Liberia (RANKING: 182 COUNTER: 6)
# not available in demo dataset -> Lesotho (RANKING: 183 COUNTER: 6)
# not available in demo dataset -> Turks & Caicos Islands (RANKING: 184 COUNTER: 6)
# not available in demo dataset -> British Virgin Islands (RANKING: 185 COUNTER: 5)
# not available in demo dataset -> St. Kitts & Nevis (RANKING: 186 COUNTER: 5)
# not available in demo dataset -> Antigua & Barbuda (RANKING: 187 COUNTER: 5)
# not available in demo dataset -> Turkmenistan (RANKING: 188 COUNTER: 5)
# not available in demo dataset -> Greenland (RANKING: 189 COUNTER: 5)
# not available in demo dataset -> Syria (RANKING: 190 COUNTER: 4)
# not available in demo dataset -> Djibouti (RANKING: 191 COUNTER: 4)
# not available in demo dataset -> Burundi (RANKING: 192 COUNTER: 3)
# not available in demo dataset -> Vanuatu (RANKING: 193 COUNTER: 3)
# not available in demo dataset -> Comoros (RANKING: 194 COUNTER: 2)
# not available in demo dataset -> Central African Republic (RANKING: 195 COUNTER: 2)
# not available in demo dataset -> Dominica (RANKING: 196 COUNTER: 2)
# not available in demo dataset -> Northern Mariana Islands (RANKING: 197 COUNTER: 1)
# not available in demo dataset -> St. Vincent & Grenadines (RANKING: 198 COUNTER: 1)
# not available in demo dataset -> Isle of Man (RANKING: 199 COUNTER: 1)
# not available in demo dataset -> Samoa (RANKING: 200 COUNTER: 1)
# not available in demo dataset -> São Tomé & Príncipe (RANKING: 201 COUNTER: 1)

# %% [markdown]
# As you can see this solution is not perfect, but it is effective in a very high percentage of cases and automatic. Later we made a supra query to show only the RANKING 1.

# %%
city_country_query = """
SELECT 
    Country,
    City
FROM (
        SELECT geoNetwork.city City, 
            geoNetwork.country Country,
            Count(*) Count, 
            ROW_NUMBER() OVER (PARTITION BY geoNetwork.city ORDER BY Count(*) DESC) AS row_num 
        FROM `bigquery-public-data.google_analytics_sample.*`
        GROUP BY Country, City
        ORDER BY City, row_num )
WHERE row_num = 1
ORDER BY Country, City
"""
city_country_result = bq.query(city_country_query).to_dataframe()

for i in range(city_country_result.shape[0]):
    print(str(city_country_result.iloc[i]['Country']) + ' -> ' + str(city_country_result.iloc[i]['City']) )
# Out:
# Albania -> Tirana
# Argentina -> Buenos Aires
# Argentina -> Cordoba
# Argentina -> Mar del Plata
# Argentina -> Pinamar
# Argentina -> Rosario
# Argentina -> Santa Fe
# Australia -> Adelaide
# Australia -> Brisbane
# Australia -> Melbourne
# Australia -> Perth
# Australia -> Sydney
# Australia -> Wollongong
# Austria -> Hallein
# Austria -> Saint Polten
# Austria -> Salzburg
# Austria -> Vienna
# Azerbaijan -> Baku
# Bangladesh -> Dhaka
# Belarus -> Brest
# Belarus -> Minsk
# Belgium -> Antwerp
# Belgium -> Bruges
# Belgium -> Brussels
# Belgium -> Ghent
# Belgium -> Kortrijk
# Belgium -> Leuven
# Belgium -> Mechelen
# Belgium -> Zaventem
# Brazil -> Atibaia
# Brazil -> Belo Horizonte
# Brazil -> Brasilia
# Brazil -> Campinas
# Brazil -> Cuiaba
# Brazil -> Curitiba
# Brazil -> Florianopolis
# Brazil -> Fortaleza
# Brazil -> Goiania
# Brazil -> Manaus
# Brazil -> Porto Alegre
# Brazil -> Recife
# Brazil -> Ribeirao Preto
# Brazil -> Rio de Janeiro
# Brazil -> Salvador
# Brazil -> Sao Paulo
# Brazil -> Vila Velha
# Bulgaria -> Sofia
# Cambodia -> Phnom Penh
# Canada -> Barrie
# Canada -> Brampton
# Canada -> Burnaby
# Canada -> Calgary
# Canada -> Charlottetown
# Canada -> Deep River
# Canada -> Edmonton
# Canada -> Gatineau
# Canada -> Kitchener
# Canada -> Mississauga
# Canada -> Montreal
# Canada -> New Westminster
# Canada -> Ottawa
# Canada -> Quebec City
# Canada -> Sherbrooke
# Canada -> St. John's
# Canada -> Toronto
# Canada -> Vancouver
# Canada -> Waterloo
# Canada -> Winnipeg
# Chile -> Santiago
# Chile -> Valparaiso
# China -> Beijing
# China -> Guangzhou
# China -> Hangzhou
# China -> Ningbo
# China -> Shanghai
# Colombia -> Barranquilla
# Colombia -> Bogota
# Colombia -> Cali
# Colombia -> Medellin
# Croatia -> Osijek
# Croatia -> Zagreb
# Czechia -> Brno
# Czechia -> Decin
# Czechia -> Hradec Kralove
# Czechia -> Olomouc
# Czechia -> Ostrava
# Czechia -> Prague
# Denmark -> Aalborg
# Denmark -> Copenhagen
# Denmark -> Esbjerg
# Denmark -> Frederiksberg
# Denmark -> Greve Strand
# Denmark -> Odense
# Denmark -> Roskilde
# Denmark -> Vejle
# Denmark -> Viby
# Ecuador -> Quito
# Egypt -> Alexandria
# Egypt -> Cairo
# El Salvador -> San Salvador
# Estonia -> Tallinn
# Finland -> Helsinki
# Finland -> Tampere
# France -> Annecy-le-Vieux
# France -> Bordeaux
# France -> Chambery
# France -> Chevilly Larue
# France -> Clermont-Ferrand
# France -> Courbevoie
# France -> Issy-les-Moulineaux
# France -> Lille
# France -> Lyon
# France -> Marseille
# France -> Metz
# France -> Montigny-le-Bretonneux
# France -> Montreuil
# France -> Nantes
# France -> Nice
# France -> Paris
# France -> Pessac
# France -> Pontivy
# France -> Quimper
# France -> Reims
# France -> Saint-Ouen-l'Aumone
# France -> Seclin
# France -> Talence
# France -> Vannes
# France -> Villeneuve-d'Ascq
# France -> Vincennes
# Georgia -> Tbilisi
# Germany -> Aalen
# Germany -> Amberg
# Germany -> Berlin
# Germany -> Bremen
# Germany -> Cologne
# Germany -> Dusseldorf
# Germany -> Frankfurt
# Germany -> Furth
# Germany -> Hamburg
# Germany -> Munich
# Germany -> Nuremberg
# Germany -> Spaichingen
# Germany -> Stuttgart
# Germany -> Weingarten
# Greece -> Athens
# Greece -> Nea Erythraia
# Greece -> Thessaloniki
# Guatemala -> Guatemala City
# Hong Kong -> Hong Kong
# Hungary -> Budapest
# India -> Ahmedabad
# India -> Belagavi
# India -> Bengaluru
# India -> Bhubaneswar
# India -> Chandigarh
# India -> Chennai
# India -> Coimbatore
# India -> Erode
# India -> Gurgaon
# India -> Guwahati
# India -> Hyderabad
# India -> Indore
# India -> Jaipur
# India -> Kharagpur
# India -> Kochi
# India -> Kolkata
# India -> Lucknow
# India -> Ludhiana
# India -> Mumbai
# India -> Nanded
# India -> Navi Mumbai
# India -> New Delhi
# India -> Noida
# India -> Patna
# India -> Pune
# India -> Surat
# India -> Thane
# India -> Vadodara
# Indonesia -> Bandung
# Indonesia -> Bekasi
# Indonesia -> Depok
# Indonesia -> Jakarta
# Indonesia -> Makassar
# Indonesia -> Medan
# Indonesia -> Semarang
# Indonesia -> Surabaya
# Ireland -> Cork
# Ireland -> Dublin
# Ireland -> Dundalk
# Ireland -> Greystones
# Israel -> Herzliya
# Israel -> Kiryat Ono
# Israel -> Netanya
# Israel -> Ramat Gan
# Israel -> Rishon LeTsiyon
# Israel -> Tel Aviv-Yafo
# Italy -> Alba
# Italy -> Bologna
# Italy -> Cagliari
# Italy -> Milan
# Italy -> Naples
# Italy -> Padua
# Italy -> Parma
# Italy -> Pescara
# Italy -> Prato
# Italy -> Rome
# Italy -> Turin
# Japan -> Chiyoda
# Japan -> Chuo
# Japan -> Fukui
# Japan -> Kumamoto
# Japan -> Minato
# Japan -> Miyazaki
# Japan -> Nagano
# Japan -> Nagoya
# Japan -> Naha
# Japan -> Osaka
# Japan -> Sakai
# Japan -> Sapporo
# Japan -> Shibuya
# Japan -> Shinjuku
# Japan -> Yokohama
# Jordan -> Amã
# Kazakhstan -> Almaty
# Kenya -> Nairobi
# Kuwait -> Kuwait City
# Latvia -> Riga
# Lebanon -> Beirut
# Lithuania -> Vilnius
# Luxembourg -> Luxembourg City
# Macedonia (FYROM) -> Skopje
# Malaysia -> Cyberjaya
# Malaysia -> Ipoh
# Malaysia -> Johor Bahru
# Malaysia -> Kampar
# Malaysia -> Kuala Lumpur
# Malaysia -> Petaling Jaya
# Malaysia -> Shah Alam
# Malaysia -> Subang Jaya
# Mexico -> Cancun
# Mexico -> Culiacan
# Mexico -> Guadalajara
# Mexico -> Hermosillo
# Mexico -> Leon
# Mexico -> Mexico City
# Mexico -> Monterrey
# Mexico -> Santiago de Queretaro
# Mexico -> Tijuana
# Mexico -> Zapopan
# Moldova -> Chisinau
# Mongolia -> Ulaanbaatar
# Morocco -> Casablanca
# Netherlands -> 's Hertogenbosch
# Netherlands -> Amersfoort
# Netherlands -> Amsterdam
# Netherlands -> Arnhem
# Netherlands -> Breda
# Netherlands -> Eindhoven
# Netherlands -> Groningen
# Netherlands -> Leusden
# Netherlands -> Oegstgeest
# Netherlands -> Oude Meer
# Netherlands -> Rotterdam
# Netherlands -> Schagen
# Netherlands -> The Hague
# Netherlands -> Utrecht
# Netherlands -> Zwolle
# New Zealand -> Auckland
# New Zealand -> Wellington
# Nigeria -> Lagos
# Norway -> Birkenes
# Norway -> Oslo
# Pakistan -> Faisalabad
# Pakistan -> Islamabad
# Pakistan -> Karachi
# Pakistan -> Lahore
# Panama -> La Chorrera
# Paraguay -> Asuncion
# Peru -> Arequipa
# Peru -> La Victoria
# Peru -> Piura
# Peru -> Santiago de Surco
# Philippines -> Cebu City
# Philippines -> Davao City
# Philippines -> Makati
# Philippines -> Manila
# Philippines -> Muntinlupa
# Philippines -> Pasig
# Philippines -> Quezon City
# Philippines -> Taguig
# Poland -> Katowice
# Poland -> Koszalin
# Poland -> Krakow
# Poland -> Poznan
# Poland -> Rzeszow
# Poland -> Szczecin
# Poland -> Warsaw
# Poland -> Wroclaw
# Portugal -> Faro
# Portugal -> Leiria
# Portugal -> Lisbon
# Qatar -> Doha
# Romania -> Alba Iulia
# Romania -> Bucharest
# Romania -> Cluj-Napoca
# Romania -> Deva
# Romania -> Iasi
# Romania -> Oradea
# Romania -> Sibiu
# Romania -> Targu Mures
# Romania -> Timisoara
# Russia -> Kovrov
# Russia -> Moscow
# Russia -> Petergof
# Russia -> Saint Petersburg
# Russia -> Vladimir
# Russia -> Vladivostok
# Saudi Arabia -> Jeddah
# Saudi Arabia -> Medina
# Saudi Arabia -> Riyadh
# Serbia -> Belgrade
# Singapore -> Singapore
# Slovakia -> Bratislava
# Slovakia -> Kosice
# Slovenia -> Ljubljana
# South Africa -> Cape Town
# South Africa -> Randburg
# South Africa -> Sandton
# South Africa -> Westville
# South Korea -> Daegu
# South Korea -> Seongnam-si
# South Korea -> Seoul
# Spain -> Alicante
# Spain -> Almeria
# Spain -> Barcelona
# Spain -> Bilbao
# Spain -> Ciudad Real
# Spain -> Elche
# Spain -> Gijon
# Spain -> Granada
# Spain -> Madrid
# Spain -> Malaga
# Spain -> Pozuelo de Alarcon
# Spain -> Sabadell
# Spain -> Sant Cugat del Valles
# Spain -> Seville
# Spain -> Toledo
# Spain -> Valencia
# Spain -> Villafranca del Castillo
# Spain -> Zamudio
# Spain -> Zaragoza
# Sri Lanka -> Colombo
# Sweden -> Gothenburg
# Sweden -> Stockholm
# Switzerland -> Geneva
# Switzerland -> Lausanne
# Switzerland -> Zurich
# Taiwan -> (not set)
# Taiwan -> Dacun Township
# Taiwan -> Hukou Township
# Taiwan -> Longtan District
# Taiwan -> Minxiong Township
# Taiwan -> Neipu Township
# Taiwan -> Taoyuan District
# Taiwan -> Toufen City
# Taiwan -> Zaoqiao Township
# Taiwan -> Zhongli District
# Taiwan -> Zhudong Township
# Thailand -> Bangkok
# Thailand -> Hua Hin
# Thailand -> Mueang Chiang Mai District
# Thailand -> Mueang Khon Kaen District
# Thailand -> Mueang Nakhon Ratchasima District
# Thailand -> Mueang Phitsanulok District
# Thailand -> Mueang Songkhla District
# Thailand -> Nakhon Pathom
# Tunisia -> Tunis
# Turkey -> Adana
# Turkey -> Ankara
# Turkey -> Antalya
# Turkey -> Aydin
# Turkey -> Bursa
# Turkey -> Erzurum
# Turkey -> Eskisehir
# Turkey -> Gaziantep
# Turkey -> Istanbul
# Turkey -> Izmir
# Turkey -> Kayseri
# Turkey -> Konya
# Turkey -> Mersin
# Turkey -> Samsun
# Turkey -> Trabzon
# Ukraine -> Dnipro
# Ukraine -> Kharkiv
# Ukraine -> Kiev
# Ukraine -> Kyiv
# Ukraine -> Lviv
# Ukraine -> Odessa
# United Arab Emirates -> Abu Dhabi
# United Arab Emirates -> Dubai
# United Arab Emirates -> Sharjah
# United Kingdom -> Aberdeen
# United Kingdom -> Altrincham
# United Kingdom -> Barnsley
# United Kingdom -> Bath
# United Kingdom -> Birmingham
# United Kingdom -> Bournemouth
# United Kingdom -> Bristol
# United Kingdom -> Canterbury
# United Kingdom -> Cardiff
# United Kingdom -> Coventry
# United Kingdom -> Egham
# United Kingdom -> Fareham
# United Kingdom -> Glasgow
# United Kingdom -> Leeds
# United Kingdom -> Lincoln
# United Kingdom -> Liverpool
# United Kingdom -> London
# United Kingdom -> Manchester
# United Kingdom -> Molesey
# United Kingdom -> Nottingham
# United Kingdom -> Oxford
# United Kingdom -> Salford
# United Kingdom -> Sheffield
# United Kingdom -> Telford
# United Kingdom -> Watford
# United Kingdom -> Wrexham
# United States -> Akron
# United States -> Allendale Charter Township
# United States -> Amherst
# United States -> Anaheim
# United States -> Ann Arbor
# United States -> Appleton
# United States -> Ashburn
# United States -> Atlanta
# United States -> Atwater
# United States -> Austin
# United States -> Avon
# United States -> Ballinger
# United States -> Baltimore
# United States -> Bellevue
# United States -> Bellflower
# United States -> Bellingham
# United States -> Berkeley
# United States -> Boardman
# United States -> Boise
# United States -> Boston
# United States -> Bothell
# United States -> Boulder
# United States -> Bozeman
# United States -> Brookline
# United States -> Burlington
# United States -> Byron
# United States -> Cambridge
# United States -> Camden
# United States -> Campbell
# United States -> Carrollton
# United States -> Chamblee
# United States -> Charlotte
# United States -> Charlottesville
# United States -> Chicago
# United States -> Chico
# United States -> Chino
# United States -> Cincinnati
# United States -> Coffeyville
# United States -> College Park
# United States -> Collegeville
# United States -> Columbia
# United States -> Columbus
# United States -> Council Bluffs
# United States -> Culpeper
# United States -> Cupertino
# United States -> Dahlonega
# United States -> Dallas
# United States -> Daly City
# United States -> Danville
# United States -> Denver
# United States -> Detroit
# United States -> Douglasville
# United States -> Druid Hills
# United States -> East Lansing
# United States -> Eau Claire
# United States -> Edison
# United States -> El Paso
# United States -> Evans
# United States -> Evanston
# United States -> Farmington Hills
# United States -> Forest Park
# United States -> Fort Collins
# United States -> Fort Worth
# United States -> Fremont
# United States -> Fresno
# United States -> Goose Creek
# United States -> Greer
# United States -> Hamden
# United States -> Hayward
# United States -> Honolulu
# United States -> Houston
# United States -> Indianapolis
# United States -> Irvine
# United States -> Jacksonville
# United States -> Jersey City
# United States -> Johnson City
# United States -> Kalamazoo
# United States -> Kansas City
# United States -> Kirkland
# United States -> LaFayette
# United States -> Laguna Beach
# United States -> Lake Oswego
# United States -> Las Vegas
# United States -> Lawrence Township
# United States -> Lehi
# United States -> Lenoir
# United States -> Lewisville
# United States -> Lexington
# United States -> Los Angeles
# United States -> Los Gatos
# United States -> Louisville
# United States -> Madison
# United States -> Mankato
# United States -> Marlboro
# United States -> McAllen
# United States -> Memphis
# United States -> Menlo Park
# United States -> Miami
# United States -> Miami Beach
# United States -> Milpitas
# United States -> Milwaukee
# United States -> Minneapolis
# United States -> Mountain View
# United States -> Nashville
# United States -> New Orleans
# United States -> New York
# United States -> Newark
# United States -> Newtonville
# United States -> Norfolk
# United States -> Normandy
# United States -> North Attleborough
# United States -> North Richland Hills
# United States -> Oakland
# United States -> Okemos
# United States -> Omaha
# United States -> Oneonta
# United States -> Orem
# United States -> Orlando
# United States -> Oshkosh
# United States -> Overland Park
# United States -> Oviedo
# United States -> Palo Alto
# United States -> Panama City
# United States -> Paradise
# United States -> Parsippany-Troy Hills
# United States -> Philadelphia
# United States -> Phoenix
# United States -> Piscataway Township
# United States -> Pittsburgh
# United States -> Plano
# United States -> Pleasanton
# United States -> Portland
# United States -> Pryor
# United States -> Pueblo
# United States -> Raleigh
# United States -> Redmond
# United States -> Redondo Beach
# United States -> Redwood City
# United States -> Rexburg
# United States -> Richardson
# United States -> Ridgewood
# United States -> Riverside
# United States -> Rockwood
# United States -> Sacramento
# United States -> Saint Paul
# United States -> Salem
# United States -> Salt Lake City
# United States -> San Antonio
# United States -> San Bruno
# United States -> San Carlos
# United States -> San Diego
# United States -> San Francisco
# United States -> San Jose
# United States -> San Marcos
# United States -> San Mateo
# United States -> Sandy
# United States -> Sandy Springs
# United States -> Santa Ana
# United States -> Santa Clara
# United States -> Santa Monica
# United States -> Saratoga
# United States -> Seattle
# United States -> Shiocton
# United States -> Smyrna
# United States -> South El Monte
# United States -> South San Francisco
# United States -> Springfield
# United States -> St. Louis
# United States -> Stanford
# United States -> Sunnyvale
# United States -> Syracuse
# United States -> Tallahassee
# United States -> Tampa
# United States -> Tempe
# United States -> The Dalles
# United States -> Thornton
# United States -> Tigard
# United States -> Towson
# United States -> Tucson
# United States -> Union City
# United States -> University Park
# United States -> Villanova
# United States -> Walnut Creek
# United States -> Washington
# United States -> Wellesley
# United States -> Westlake Village
# United States -> Wheaton
# United States -> Wheeling
# United States -> White Plains
# United States -> Whitewater
# United States -> Woodbridge Township
# United States -> not available in demo dataset
# Uruguay -> Montevideo
# Venezuela -> Cabimas
# Venezuela -> Caracas
# Venezuela -> Maracaibo
# Vietnam -> Bien Hoa
# Vietnam -> Buon Ma Thuot
# Vietnam -> Can Tho
# Vietnam -> Cao Lanh
# Vietnam -> Da Nang
# Vietnam -> Dalat
# Vietnam -> Ha Tinh
# Vietnam -> Hai Duong
# Vietnam -> Hai Phong
# Vietnam -> Hanoi
# Vietnam -> Ho Chi Minh City
# Vietnam -> Hoi An
# Vietnam -> Hue
# Vietnam -> My Tho
# Vietnam -> Nam Djinh
# Vietnam -> Nha Trang
# Vietnam -> Phan Thiet
# Vietnam -> Pleiku
# Vietnam -> Quang Ngai
# Vietnam -> Qui Nhon
# Vietnam -> Rach Gia
# Vietnam -> Thai Binh
# Vietnam -> Thai Nguyen
# Vietnam -> Thanh Hoa
# Vietnam -> Vinh
# Vietnam -> Vung Tau

# %% [markdown]
# To correct the dataset city_result, the query should be merged with city_country_query.

# %%
#We store this query in a variable because it will be used twice in the subsequent query.
country_sub_query = """(
SELECT 
    Country 
FROM ( 
        SELECT geoNetwork.country Country, COUNT(*) Visits 
            FROM 
                `bigquery-public-data.google_analytics_sample.*`
                GROUP BY Country ORDER BY Visits DESC) S 
LIMIT 1)
"""


city_sol_query = """
SELECT geoNetwork.city City,
        COUNT(*) Visits
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
WHERE geoNetwork.country = """+ country_sub_query  +""" AND 
        geoNetwork.city  IN (SELECT 
                        City
                    FROM (
                            SELECT geoNetwork.city City, geoNetwork.country Country,Count(*) Contador, 
                            ROW_NUMBER() OVER (PARTITION BY geoNetwork.city ORDER BY Count(*) DESC) AS row_num 
                                FROM `bigquery-public-data.google_analytics_sample.*` GROUP BY Country, City )
            WHERE  row_num = 1 AND Country = """+ country_sub_query  +""")
GROUP BY geoNetwork.city 
ORDER BY Visits DESC
"""
city_sol_result = bq.query(city_sol_query).to_dataframe()

print('Number of records before -> Number of records after\n' 
      + str(city_result.shape[0]) + ' -> ' + str(city_sol_result.shape[0]) 
      + '\nReduction percentage: ' + str(round( 100*(city_result.shape[0]- city_sol_result.shape[0])/city_result.shape[0],2)) + ' %'  )
# Out:
# Number of records before -> Number of records after
# 256 -> 192
# Reduction percentage: 25.0 %

# %% [markdown]
# SOLVED!
# The dataset would be clean by now. And with a 25% reduction in data.

# %% [markdown]
# Visits by type of social engagement

# %%
social_query = """
SELECT socialEngagementType SocialEngadgementType,
        COUNT(*) Visits
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
GROUP BY SocialEngadgementType
ORDER BY Visits DESC
"""
social_result = bq.query(social_query).to_dataframe()
social_result
# Out:
#   SocialEngadgementType  Visits
# 0  Not Socially Engaged  903653

# %% [markdown]
# # Visits by channel grouping

# %%
channel_query = """
SELECT channelGrouping ChannelGrouping,
        COUNT(*) Visits
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
GROUP BY ChannelGrouping
ORDER BY Visits DESC
"""
channel_result = bq.query(channel_query).to_dataframe()
channel_result
# Out:
#   ChannelGrouping  Visits
# 0  Organic Search  381561
# 1          Social  226117
# 2          Direct  143026
# 3        Referral  104838
# 4     Paid Search   25326
# 5      Affiliates   16403
# 6         Display    6262
# 7         (Other)     120

# %% [markdown]
# Display of the result

# %%
channel_graph = channel_result.plot(kind='bar',x='ChannelGrouping',y='Visits')
channel_graph.set_title('Visits by channel grouping type')
channel_graph.legend().remove()
channel_graph.set_ylabel('Visits')
channel_graph.set_xlabel('Channel grouping type')
plt.show()

# %% [markdown]
# #  Display by month

# %%
channel_month_query = """
SELECT channelGrouping ChannelGrouping,
        CONCAT(substr(date,0,4),'-', substr(date,5,2)) Month,
        COUNT(*) Visits
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
GROUP BY ChannelGrouping, Month
ORDER BY Month, ChannelGrouping
"""
channel_month_result = bq.query(channel_month_query).to_dataframe()
channel_month_result
# Out:
#    ChannelGrouping    Month  Visits
# 0          (Other)  2016-08       2
# 1       Affiliates  2016-08    1909
# 2           Direct  2016-08   12163
# 3          Display  2016-08     449
# 4   Organic Search  2016-08   24143
# ..             ...      ...     ...
# 94         Display  2017-08      39
# 95  Organic Search  2017-08    1346
# 96     Paid Search  2017-08      70
# 97        Referral  2017-08     436
# 98          Social  2017-08     213
#
# [99 rows x 3 columns]

# %% [markdown]
#  Display of the result

# %%
#To plot multiple lines plot use a for loop
for i in range(channel_result.shape[0]):
      plt.plot(channel_month_result.loc[channel_month_result['ChannelGrouping'] == channel_result.iloc[i]["ChannelGrouping"]]['Month'],channel_month_result.loc[channel_month_result['ChannelGrouping'] == channel_result.iloc[i]["ChannelGrouping"]]['Visits'] , label = channel_result.iloc[i]["ChannelGrouping"])

plt.title('Visits per month by channel grouping type')

plt.ylabel('Visits')
# Rotation of the x axis marks to visualize it properly 
plt.xticks(rotation = '90')
# To improve the display, the legend box is taken out of the drawing area.
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.grid(True, linestyle='-.', which='major', axis = 'both' ,color='grey', alpha=.2)

#To save the plot
plt.savefig('Visits_perMonth_by_channelGrouping.png')
plt.show()

# %% [markdown]
# # Using browsers, operating systems and mobile phones
#
# Querying and obtaining the dataset

# %%
#Información compuesto por los 3 datos
device_query = """
SELECT device.browser Browser,
        device.operatingSystem OS,
        device.isMobile Smartphone,
        COUNT(*) Count
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
GROUP BY Browser, OS, Smartphone
ORDER BY Count DESC
"""
device_result = bq.query(device_query).to_dataframe()

browser_query = """
SELECT device.browser Browser,
        COUNT(*) Count
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
GROUP BY Browser
ORDER BY Count DESC
"""
browser_result = bq.query(browser_query).to_dataframe()

os_query = """
SELECT device.operatingSystem OS,
        COUNT(*) Count
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
GROUP BY OS
ORDER BY Count DESC
"""
os_result = bq.query(os_query).to_dataframe()

browser_desktop_query = """
SELECT device.browser Browser,
        COUNT(*) Count
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
        WHERE device.isMobile = False
GROUP BY Browser
ORDER BY Count DESC
"""
browser_desktop_result = bq.query(browser_desktop_query).to_dataframe()

browser_smartphone_query = """
SELECT device.browser Browser,
        COUNT(*) Count
        FROM 
            `bigquery-public-data.google_analytics_sample.*`
        WHERE device.isMobile = True
GROUP BY Browser
ORDER BY Count DESC
"""
browser_smartphone_result = bq.query(browser_smartphone_query).to_dataframe()

# %% [markdown]
# # Display of the result
# All the information is displayed in a single figure consisting of several subfigures.

# %%
# General data of the charts.
fig, ax = plt.subplots(2,2)
fig.set_figheight(16)
fig.set_figwidth(16)
fig.suptitle('OS and browser information', size = '16')

#Dividers are drawn
plt.plot([-1.75, -1.75], [-1.25, 4.5], color='grey', lw=1, clip_on=False)
plt.plot([-4.25, 1.25], [1.5, 1.5], color='grey', lw=1, clip_on=False)

#Graph 1: Position 0.0
#The DataFrame is modified to be readable, the first 5 results are printed and the rest are grouped under the label "Others"
#First the vectors are assembled
nav_res = []
cont_res = []
cont_sum = 0
for i in range(browser_result.shape[0]):
    if (i <= 4):
        nav_res.append(browser_result.iloc[i]['Browser'])
        cont_res.append(browser_result.iloc[i]['Count'])
    else:
        cont_sum += browser_result.iloc[i]['Count']
            
nav_res.append('Others')
cont_res.append(cont_sum)

#Then the dataset is formed
browser_result_print = pd.DataFrame({"Browser":nav_res, "Count":cont_res})
    
ax[0, 0].pie(browser_result_print.iloc[:]['Count'], labels = browser_result_print.iloc[:]['Browser'], autopct='%.0f%%', startangle=180)
ax[0,0].set_title('Browsers', size = '14')

#Graph 2: Position 0.1
#The same operation is performed with the operating system graphic. 
OS_res = []
cont_res = []
cont_sum = 0
for i in range(os_result.shape[0]):
    if (i <= 5):
        OS_res.append(os_result.iloc[i]['OS'])
        cont_res.append(os_result.iloc[i]['Count'])
    else:
        cont_sum += os_result.iloc[i]['Count']
            
OS_res.append('Others')
cont_res.append(cont_sum)

#Then the dataset is formed
OS_result_print = pd.DataFrame({"OS":OS_res, "Count":cont_res})

ax[0, 1].pie(OS_result_print.iloc[:]['Count'], labels = OS_result_print.iloc[:]['OS'], autopct='%.0f%%' )
ax[0,1].set_title('OS', size = '14')

#Graph 3: Position 1.0
# Use of browsers on desktop computers
nav_res = []
cont_res = []
cont_sum = 0
for i in range(browser_desktop_result.shape[0]):
    if (i <= 4):
        nav_res.append(browser_desktop_result.iloc[i]['Browser'])
        cont_res.append(browser_desktop_result.iloc[i]['Count'])
    else:
        cont_sum += browser_desktop_result.iloc[i]['Count']
            
nav_res.append('Others')
cont_res.append(cont_sum)


browser_result_desktop_print = pd.DataFrame({"Browser":nav_res, "Count":cont_res})
    
ax[1, 0].pie(browser_result_desktop_print.iloc[:]['Count'], labels = browser_result_desktop_print.iloc[:]['Browser'], autopct='%.0f%%', startangle=180 )
ax[1,0].set_title('Desktop browsers', size = '14')

#Graph 4: Position 1.1
# Use of browsers on mobile devices
nav_res = []
cont_res = []
cont_sum = 0
for i in range(browser_smartphone_result.shape[0]):
    if (i <= 4):
        nav_res.append(browser_smartphone_result.iloc[i]['Browser'])
        cont_res.append(browser_smartphone_result.iloc[i]['Count'])
    else:
        cont_sum += browser_smartphone_result.iloc[i]['Count']
            
nav_res.append('Others')
cont_res.append(cont_sum)


browser_smartphone_result_print = pd.DataFrame({"Browser":nav_res, "Count":cont_res})
    
ax[1, 1].pie(browser_smartphone_result_print.iloc[:]['Count'], labels = browser_smartphone_result_print.iloc[:]['Browser'], autopct='%.0f%%' )
ax[1,1].set_title('Mobile browsers', size = '14')
plt.savefig('OS_and_browser_info.png')
